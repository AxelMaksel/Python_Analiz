# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv',encoding='cp1251', index_col = 'laptop_ID')

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)
# 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
# 1.4 Удалите признаки Memory и ScreenResolution

# %%
df['Cpu_Company']=df.Cpu.apply(lambda x: x.split()[0])

# %%
df.sample(5)
# Out:
#           Company             Product   TypeName  Inches   ScreenResolution  \
# laptop_ID
# 1165         Dell         Vostro 5568   Notebook    15.6  Full HD 1920x1080
# 1126         Dell         Vostro 3559   Notebook    15.6           1366x768
# 256          Asus  ROG G752VSK-GC493T     Gaming    17.3  Full HD 1920x1080
# 882        Lenovo   IdeaPad 110-15ISK   Notebook    15.6  Full HD 1920x1080
# 762        Lenovo       Thinkpad T460  Ultrabook    14.0  Full HD 1920x1080
#
#                                    Cpu   Ram                Memory  \
# laptop_ID
# 1165        Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1126        Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 256        Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 882           Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 762         Intel Core i5 6200U 2.3GHz   4GB             180GB SSD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# laptop_ID
# 1165          Nvidia GeForce 940MX  Windows 10  2.18kg      1009.90
# 1126            AMD Radeon R5 M315   Windows 7  2.24kg       769.15
# 256        Nvidia GeForce GTX 980M  Windows 10   4.3kg      1799.00
# 882             AMD Radeon R5 M430       No OS   2.2kg       479.00
# 762          Intel HD Graphics 520  Windows 10   1.7kg      1096.00
#
#           Cpu_Company
# laptop_ID
# 1165            Intel
# 1126            Intel
# 256             Intel
# 882             Intel
# 762             Intel

# %% [markdown]
# 256GB SSD + 1TB HDD

# %%
def func(lst):
    sum_GB = 0 
    for el in lst.split():
        if 'GB' in el:
            sum_GB += float(el[:-2])
        elif 'TB' in el:
            sum_GB += float(el[:-2]) * 1024
    return int(sum_GB)

df['Memory_Amount'] = df.Memory.apply(func)
df.sample(10)
# Out:
#           Company                                Product            TypeName  \
# laptop_ID
# 236            HP    15-rb013nv (E2-9000e/4GB/500GB/W10)            Notebook
# 356          Dell                                 XPS 15            Notebook
# 978            HP                            ProBook 450            Notebook
# 1246       Lenovo                     IdeaPad Y700-15ISK              Gaming
# 1082         Dell                          Inspiron 5368  2 in 1 Convertible
# 932          Dell                          Inspiron 7567              Gaming
# 343            HP                          Elitebook 850            Notebook
# 170          Acer                               Aspire 3            Notebook
# 217            HP  15-bs018nq (i3-6006U/4GB/500GB/FHD/No            Notebook
# 546        Lenovo                          Thinkpad E470            Notebook
#
#            Inches                           ScreenResolution  \
# laptop_ID
# 236          15.6                                   1366x768
# 356          15.6        4K Ultra HD / Touchscreen 3840x2160
# 978          15.6                                   1366x768
# 1246         15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1082         13.3            Full HD / Touchscreen 1920x1080
# 932          15.6                          Full HD 1920x1080
# 343          15.6                          Full HD 1920x1080
# 170          15.6                                   1366x768
# 217          15.6                          Full HD 1920x1080
# 546          14.0                IPS Panel Full HD 1920x1080
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 236                   AMD E-Series 9000e 1.5GHz   4GB             500GB HDD
# 356                 Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 978                 Intel Core i5 7200U 2.50GHz   8GB               1TB HDD
# 1246                Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1TB HDD
# 1082                 Intel Core i7 6500U 2.5GHz   8GB             256GB SSD
# 932                 Intel Core i7 7700HQ 2.8GHz  16GB  128GB SSD +  1TB HDD
# 343                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 170        Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 217                    Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 546                  Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
#
#                                   Gpu       OpSys  Weight  Price_euros  \
# laptop_ID
# 236                     AMD Radeon R2  Windows 10   2.1kg       330.00
# 356           Nvidia GeForce GTX 1050  Windows 10  2.06kg      2027.42
# 978              Nvidia GeForce 930MX  Windows 10  2.04kg       846.50
# 1246          Nvidia GeForce GTX 960M  Windows 10   2.6kg      1029.00
# 1082            Intel HD Graphics 520  Windows 10  1.62kg       798.01
# 932        Nvidia GeForce GTX 1050 Ti  Windows 10   2.6kg      1349.00
# 343             Intel HD Graphics 620  Windows 10  1.84kg      1144.00
# 170             Intel HD Graphics 505  Windows 10   2.1kg       363.51
# 217             Intel HD Graphics 520       No OS   2.1kg       349.00
# 546              Nvidia GeForce 940MX  Windows 10  1.87kg       859.00
#
#           Cpu_Company  Memory_Amount
# laptop_ID
# 236               AMD            500
# 356             Intel            512
# 978             Intel           1024
# 1246            Intel           1152
# 1082            Intel            256
# 932             Intel           1152
# 343             Intel            256
# 170             Intel           1024
# 217             Intel            500
# 546             Intel            256

# %% [markdown]
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
# 1.4 Удалите признаки Memory и ScreenResolution
#
#  256GB SSD + 1TB HDD

# %%
def func1(lst):
    new_l = ''
    s = lst.split()
    for el in s:
        if el.isalpha():
            if new_l:
                if new_l[-1] == 'D' or new_l[-1] == 'e':
                    new_l += ', '
                else:
                    new_l += ' '
            new_l += el
    return new_l
func1('256GB SSD + 1TB HDD')
# Out:
# 'SSD, HDD'

# %%
df['Memory_Type'] = df.Memory.apply(func1)
df.sample(50)
# Out:
#              Company                                    Product  \
# laptop_ID
# 976             Acer                        Aspire F5-573G-510L
# 672              MSI                             GP72VR Leopard
# 595           Lenovo                         Ideapad 320-15IKBR
# 296             Asus  FX753VD-GC071T (i7-7700HQ/8GB/1TB/GeForce
# 109           Lenovo                          Ideapad 310-15ISK
# 705             Asus                            Chromebook Flip
# 1234            Acer                                    E5 774G
# 570           Lenovo                               Thinkpad P71
# 50              Asus       X751NV-TY001T (N4200/4GB/1TB/GeForce
# 1              Apple                                MacBook Pro
# 47            Lenovo                          IdeaPad 320-15ISK
# 1090          Lenovo                          IdeaPad 300-17ISK
# 643             Asus                               VivoBook Pro
# 803            Apple                                MacBook 12"
# 191           Lenovo                         Legion Y520-15IKBN
# 107        Microsoft                             Surface Laptop
# 818           Lenovo                          IdeaPad 310-15IKB
# 627               HP                                ProBook 650
# 805             Asus           R417NA-RS01 (N3350/4GB/32GB/W10)
# 871           Lenovo                              ThinkPad E570
# 401             Dell                              Inspiron 5567
# 423             Dell                              Latitude 3380
# 1189              HP                                ProBook 450
# 1077            Dell                              Inspiron 5567
# 265             Dell                              Inspiron 5770
# 635             Asus  Q304UA-BHI5T11 (i5-7200U/6GB/1TB/FHD/W10)
# 704           Lenovo                             Yoga 910-13IKB
# 729               HP                              Pavilion X360
# 1235          Lenovo                          IdeaPad 320-17IKB
# 960             Dell                              Latitude 7280
# 1037              HP                                ProBook 440
# 551             Asus                     VivoBook X540YA-XX519T
# 388             Asus                                  ROG Strix
# 1170          Lenovo            B51-80 (i5-6200U/8GB/1TB/Radeon
# 462             Dell                              Inspiron 3168
# 413          Toshiba                          Portege Z30-C-16P
# 534           Lenovo                          IdeaPad 320-15ISK
# 564           Lenovo                          IdeaPad 320-17IKB
# 390             Asus                               Zenbook Flip
# 199               HP                                ProBook 470
# 1032         Toshiba                            Tecra Z40-C-12Z
# 133             Dell                              Inspiron 5567
# 377             Acer                                   Aspire 3
# 770             Dell                              Latitude 7280
# 639             Dell                              Inspiron 7567
# 235             Asus                        Pro P2540UA-XO0198T
# 730           Lenovo                             ThinkPad T470s
# 914             Dell                                     XPS 13
# 1309            Acer                             Aspire ES1-531
# 515               HP                            Envy 13-AB002nv
#
#                      TypeName  Inches                    ScreenResolution  \
# laptop_ID
# 976                  Notebook    15.6                   Full HD 1920x1080
# 672                    Gaming    17.3                   Full HD 1920x1080
# 595                  Notebook    15.6                Touchscreen 1366x768
# 296                    Gaming    17.3                   Full HD 1920x1080
# 109                  Notebook    15.6                   Full HD 1920x1080
# 705        2 in 1 Convertible    12.5     Full HD / Touchscreen 1920x1080
# 1234                 Notebook    17.3                            1600x900
# 570                  Notebook    17.3         IPS Panel Full HD 1920x1080
# 50                   Notebook    17.3                            1366x768
# 1                   Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 47                   Notebook    15.6                            1366x768
# 1090                 Notebook    17.3                            1600x900
# 643                  Notebook    15.6                   Full HD 1920x1080
# 803                 Ultrabook    12.0  IPS Panel Retina Display 2304x1440
# 191                    Gaming    15.6         IPS Panel Full HD 1920x1080
# 107                 Ultrabook    13.5               Touchscreen 2256x1504
# 818                  Notebook    15.6                   Full HD 1920x1080
# 627                  Notebook    14.0                            1366x768
# 805                  Notebook    14.0                            1366x768
# 871                  Notebook    15.6         IPS Panel Full HD 1920x1080
# 401                  Notebook    15.6                   Full HD 1920x1080
# 423                  Notebook    13.3                            1366x768
# 1189                 Notebook    15.6                   Full HD 1920x1080
# 1077                 Notebook    15.6                   Full HD 1920x1080
# 265                  Notebook    17.3                   Full HD 1920x1080
# 635        2 in 1 Convertible    13.3     Full HD / Touchscreen 1920x1080
# 704        2 in 1 Convertible    14.0     Full HD / Touchscreen 1920x1080
# 729        2 in 1 Convertible    13.3      IPS Panel Touchscreen 1366x768
# 1235                 Notebook    17.3                            1600x900
# 960                 Ultrabook    12.5     Full HD / Touchscreen 1920x1080
# 1037                 Notebook    14.0                   Full HD 1920x1080
# 551                  Notebook    15.6                            1366x768
# 388                    Gaming    15.6         IPS Panel Full HD 1920x1080
# 1170                 Notebook    15.6                   Full HD 1920x1080
# 462        2 in 1 Convertible    11.6                Touchscreen 1366x768
# 413                 Ultrabook    13.3                   Full HD 1920x1080
# 534                  Notebook    15.6                            1366x768
# 564                  Notebook    17.3                            1600x900
# 390                 Ultrabook    13.3     Full HD / Touchscreen 1920x1080
# 199                  Notebook    17.3         IPS Panel Full HD 1920x1080
# 1032                 Notebook    14.0         IPS Panel Full HD 1920x1080
# 133                  Notebook    15.6                            1366x768
# 377                  Notebook    15.6                            1366x768
# 770                 Ultrabook    12.5                   Full HD 1920x1080
# 639                    Gaming    15.6                   Full HD 1920x1080
# 235                  Notebook    15.6                            1366x768
# 730                 Ultrabook    14.0         IPS Panel Full HD 1920x1080
# 914        2 in 1 Convertible    13.3     Full HD / Touchscreen 1920x1080
# 1309                 Notebook    15.6                            1366x768
# 515                 Ultrabook    13.3         IPS Panel Full HD 1920x1080
#
#                                             Cpu   Ram                Memory  \
# laptop_ID
# 976                  Intel Core i5 7200U 2.5GHz  12GB  128GB SSD +  1TB HDD
# 672                 Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 595                  Intel Core i7 8550U 1.8GHz  12GB               1TB HDD
# 296                 Intel Core i7 7700HQ 2.8GHz   8GB               1TB HDD
# 109                    Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 705                 Intel Core M M3-6Y30 0.9GHz   4GB    64GB Flash Storage
# 1234                   Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 570                 Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 50         Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 1                          Intel Core i5 2.3GHz   8GB             128GB SSD
# 47                     Intel Core i3 6006U 2GHz   4GB             128GB SSD
# 1090                 Intel Core i5 6200U 2.3GHz   8GB             1.0TB HDD
# 643                 Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# 803                         Intel Core M 1.2GHz   8GB   512GB Flash Storage
# 191                 Intel Core i5 7300HQ 2.5GHz   8GB             256GB SSD
# 107                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 818                  Intel Core i5 7200U 2.5GHz   4GB               1TB HDD
# 627                  Intel Core i5 7300U 2.6GHz   8GB             256GB SSD
# 805        Intel Celeron Dual Core N3350 1.1GHz   4GB    32GB Flash Storage
# 871                  Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 401                  Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 423                    Intel Core i3 6006U 2GHz   4GB             128GB SSD
# 1189                 Intel Core i7 8550U 1.8GHz  16GB             512GB SSD
# 1077                 Intel Core i7 7500U 2.7GHz  16GB               2TB HDD
# 265                  Intel Core i7 8550U 1.8GHz   8GB  128GB SSD +  1TB HDD
# 635                  Intel Core i5 7200U 2.5GHz   6GB               1TB HDD
# 704                  Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 729                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1235                 Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 960                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 1037                 Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 551                    AMD E-Series 7110 1.8GHz   4GB             500GB HDD
# 388                 Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 1170                 Intel Core i5 6200U 2.3GHz   8GB               1TB HDD
# 462        Intel Pentium Quad Core N3710 1.6GHz   4GB             500GB HDD
# 413                  Intel Core i7 6500U 2.5GHz  16GB             512GB SSD
# 534                    Intel Core i3 6006U 2GHz   8GB               2TB HDD
# 564                  Intel Core i7 7500U 2.7GHz   6GB  128GB SSD +  1TB HDD
# 390                  Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 199                  Intel Core i5 8250U 1.6GHz   8GB               1TB HDD
# 1032                 Intel Core i5 6200U 2.3GHz   8GB             256GB SSD
# 133                  Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 377                     AMD A9-Series 9420 3GHz   4GB             128GB SSD
# 770                  Intel Core i7 7600U 2.8GHz  16GB             256GB SSD
# 639                 Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 235                  Intel Core i3 7100U 2.4GHz   4GB               1TB HDD
# 730                  Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 914                   Intel Core i7 7Y75 1.3GHz  16GB             256GB SSD
# 1309       Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 515                  Intel Core i7 7500U 2.7GHz   8GB             512GB SSD
#
#                                     Gpu         OpSys   Weight  Price_euros  \
# laptop_ID
# 976             Nvidia GeForce GTX 950M    Windows 10    2.4kg      1009.00
# 672             Nvidia GeForce GTX 1060    Windows 10    2.7kg      1486.77
# 595               Intel HD Graphics 620    Windows 10    2.2kg       609.00
# 296             Nvidia GeForce GTX 1050    Windows 10      3kg      1187.00
# 109               Intel HD Graphics 520    Windows 10   1.85kg       414.90
# 705               Intel HD Graphics 515     Chrome OS    1.2kg       669.00
# 1234               Nvidia GeForce 940MX    Windows 10    3.3kg       598.00
# 570                 Nvidia Quadro M620M    Windows 10    3.4kg      2999.00
# 50                 Nvidia GeForce 920MX    Windows 10    2.8kg       466.00
# 1          Intel Iris Plus Graphics 640         macOS   1.37kg      1339.69
# 47                Intel HD Graphics 520         No OS    2.2kg       369.00
# 1090                 AMD Radeon R5 M330    Windows 10    3.0kg       659.00
# 643             Nvidia GeForce GTX 1050    Windows 10   1.99kg       906.62
# 803              Intel HD Graphics 5300      Mac OS X  0.920kg      1165.00
# 191             Nvidia GeForce GTX 1050         No OS    2.4kg       779.00
# 107               Intel HD Graphics 620  Windows 10 S  1.252kg      1340.00
# 818                 Nvidia GeForce 920M    Windows 10    2.4kg       609.00
# 627               Intel HD Graphics 620    Windows 10   2.31kg      1124.00
# 805               Intel HD Graphics 500    Windows 10   1.63kg       299.00
# 871               Intel HD Graphics 620    Windows 10    2.3kg       850.66
# 401                  AMD Radeon R7 M445         Linux   2.33kg       778.87
# 423               Intel HD Graphics 520    Windows 10   1.65kg       689.00
# 1189             Intel UHD Graphics 620    Windows 10    2.1kg      1159.00
# 1077                 AMD Radeon R7 M445    Windows 10   2.32kg       989.99
# 265                      AMD Radeon 530    Windows 10    2.8kg      1142.00
# 635               Intel HD Graphics 620    Windows 10    1.5kg       639.01
# 704               Intel HD Graphics 620    Windows 10   1.38kg      1749.00
# 729               Intel HD Graphics 620    Windows 10   1.58kg       836.60
# 1235              Intel HD Graphics 620         No OS    2.8kg       539.00
# 960                   Intel HD Graphics    Windows 10   1.36kg      1472.20
# 1037               Nvidia GeForce 930MX    Windows 10   1.64kg      1185.43
# 551              AMD Radeon R2 Graphics    Windows 10      2kg       349.00
# 388             Nvidia GeForce GTX 1060    Windows 10    2.3kg      1655.00
# 1170                 AMD Radeon R5 M330         No OS   2.32kg       599.00
# 462               Intel HD Graphics 405    Windows 10   1.47kg       479.00
# 413               Intel HD Graphics 520    Windows 10    1.2kg      1747.00
# 534               Nvidia GeForce 920MX          No OS    2.2kg       459.00
# 564                Nvidia GeForce 940MX    Windows 10    2.8kg       949.00
# 390               Intel HD Graphics 620    Windows 10    1.1kg      1748.90
# 199                Nvidia GeForce 930MX    Windows 10    2.5kg       914.00
# 1032              Intel HD Graphics 520    Windows 10   1.47kg      1490.00
# 133                  AMD Radeon R7 M445    Windows 10   2.36kg       638.99
# 377                       AMD Radeon R5    Windows 10    2.1kg       426.00
# 770               Intel HD Graphics 620    Windows 10   1.18kg      1859.00
# 639          Nvidia GeForce GTX 1050 Ti    Windows 10   2.62kg      1479.00
# 235               Intel HD Graphics 620    Windows 10   2.37kg       398.99
# 730               Intel HD Graphics 620    Windows 10   1.32kg      1499.00
# 914               Intel HD Graphics 615    Windows 10   1.22kg      1649.00
# 1309              Intel HD Graphics 400         Linux    2.4kg       289.00
# 515               Intel HD Graphics 620    Windows 10   1.34kg      1323.00
#
#           Cpu_Company  Memory_Amount    Memory_Type
# laptop_ID
# 976             Intel           1152       SSD, HDD
# 672             Intel           1152       SSD, HDD
# 595             Intel           1024            HDD
# 296             Intel           1024            HDD
# 109             Intel           1024            HDD
# 705             Intel             64  Flash Storage
# 1234            Intel           1024            HDD
# 570             Intel            256            SSD
# 50              Intel           1024            HDD
# 1               Intel            128            SSD
# 47              Intel            128            SSD
# 1090            Intel           1024            HDD
# 643             Intel           1024            HDD
# 803             Intel            512  Flash Storage
# 191             Intel            256            SSD
# 107             Intel            256            SSD
# 818             Intel           1024            HDD
# 627             Intel            256            SSD
# 805             Intel             32  Flash Storage
# 871             Intel           1024            HDD
# 401             Intel            256            SSD
# 423             Intel            128            SSD
# 1189            Intel            512            SSD
# 1077            Intel           2048            HDD
# 265             Intel           1152       SSD, HDD
# 635             Intel           1024            HDD
# 704             Intel            512            SSD
# 729             Intel            256            SSD
# 1235            Intel           1024            HDD
# 960             Intel            256            SSD
# 1037            Intel            256            SSD
# 551               AMD            500            HDD
# 388             Intel           1152       SSD, HDD
# 1170            Intel           1024            HDD
# 462             Intel            500            HDD
# 413             Intel            512            SSD
# 534             Intel           2048            HDD
# 564             Intel           1152       SSD, HDD
# 390             Intel            512            SSD
# 199             Intel           1024            HDD
# 1032            Intel            256            SSD
# 133             Intel           1024            HDD
# 377               AMD            128            SSD
# 770             Intel            256            SSD
# 639             Intel           1280       SSD, HDD
# 235             Intel           1024            HDD
# 730             Intel            256            SSD
# 914             Intel            256            SSD
# 1309            Intel            500            HDD
# 515             Intel            512            SSD

# %%
df.drop(columns = ['Memory','ScreenResolution'], inplace = True)
df.head(3)
# Out:
#           Company      Product   TypeName  Inches                         Cpu  \
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz
# 2           Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 3              HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
#
#            Ram                           Gpu  OpSys  Weight  Price_euros  \
# laptop_ID
# 1          8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69
# 2          8GB        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 3          8GB         Intel HD Graphics 620  No OS  1.86kg       575.00
#
#           Cpu_Company  Memory_Amount    Memory_Type
# laptop_ID
# 1               Intel            128            SSD
# 2               Intel            128  Flash Storage
# 3               Intel            256            SSD

# %% [markdown]
# 2.1 Создайте признак SSD, который изначально равен 0
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df.Memory_Type.value_counts()
# Out:
# SSD                   637
# HDD                   374
# SSD, HDD              200
# Flash Storage          74
# Hybrid                 10
# SSD, SSD                4
# SSD, Hybrid             2
# Flash Storage, HDD      1
# HDD, HDD                1
# Name: Memory_Type, dtype: int64

# %%
df['SSD'] = 0
df.loc[df['Memory_Type'] == 'SSD','SSD'] = 1

# %%
df.sample(50)
# Out:
#              Company                            Product            TypeName  \
# laptop_ID
# 888           Xiaomi                        Mi Notebook           Ultrabook
# 863             Dell                      Inspiron 5767            Notebook
# 1268            Dell                      Inspiron 3552            Notebook
# 613          Toshiba                    Tecra Z50-C-144            Notebook
# 843           Lenovo                     ThinkPad T470s            Notebook
# 728           Lenovo                        ThinkPad X1           Ultrabook
# 615           Lenovo                     Yoga 720-15IKB  2 in 1 Convertible
# 1055            Vero       V142 (X5-Z8350/2GB/32GB/W10)            Notebook
# 367             Asus             Zenbook UX410UA-GV027T            Notebook
# 453             Acer                     Aspire ES1-572            Notebook
# 791          Toshiba                    Tecra Z40-C-161           Ultrabook
# 542             Dell                      Latitude 5580            Notebook
# 924               HP                    Elitebook Folio           Ultrabook
# 46             Apple                        MacBook Pro           Ultrabook
# 1047              HP                        Probook 640            Notebook
# 241             Acer                     Aspire A315-51            Notebook
# 604           Lenovo                     Thinkpad T470p            Notebook
# 84                HP                        ProBook 440            Notebook
# 588             Dell                      Latitude 5580            Notebook
# 168             Acer                     Aspire A315-31            Notebook
# 889             Dell                        Vostro 5568            Notebook
# 617           Lenovo                       Thinkpad P51            Notebook
# 1181          Lenovo                  IdeaPad 310-15ISK            Notebook
# 923             Dell                      Latitude 5480            Notebook
# 1135            Vero   V131 (X5-Z8350/4GB/32GB/FHD/W10)            Notebook
# 213           Lenovo                 IdeaPad 320-15IKBN            Notebook
# 1255            Dell                        Vostro 3559            Notebook
# 547             Dell                             XPS 13           Ultrabook
# 801           Lenovo                      ThinkPad Yoga  2 in 1 Convertible
# 1032         Toshiba                    Tecra Z40-C-12Z            Notebook
# 669           Lenovo                  Ideapad 320-15IAP            Notebook
# 51            Lenovo                          Yoga Book  2 in 1 Convertible
# 1040              HP                        ProBook 650            Notebook
# 30                HP                        ProBook 470            Notebook
# 424               HP                     EliteBook 1040           Ultrabook
# 465        Microsoft                     Surface Laptop           Ultrabook
# 108               HP                Pavilion 14-BK001nv            Notebook
# 1157             MSI                         GP62M 7RDX              Gaming
# 188           Xiaomi                        Mi Notebook            Notebook
# 181              MSI                    GT80S 6QF-074US              Gaming
# 37              Acer                           Aspire 3            Notebook
# 107        Microsoft                     Surface Laptop           Ultrabook
# 352               HP                  Stream 14-AX001nv            Notebook
# 437          Samsung                       Chromebook 3             Netbook
# 1254              HP                      EliteBook 840           Ultrabook
# 1191          Lenovo  V110-15ISK (i5-6200U/4GB/500GB/No            Notebook
# 29              Dell                      Latitude 5590           Ultrabook
# 395           Lenovo                        ThinkPad X1  2 in 1 Convertible
# 1019              HP                      EliteBook 840            Notebook
# 151              MSI                        GE72MVR 7RG              Gaming
#
#            Inches                                   Cpu   Ram  \
# laptop_ID
# 888          13.3            Intel Core i5 6200U 2.3GHz   8GB
# 863          17.3            Intel Core i7 7500U 2.7GHz   8GB
# 1268         15.6  Intel Pentium Quad Core N3710 1.6GHz   4GB
# 613          15.6            Intel Core i7 6500U 2.5GHz   8GB
# 843          14.0            Intel Core i5 7300U 2.6GHz   8GB
# 728          14.0            Intel Core i7 6500U 2.5GHz   8GB
# 615          15.6           Intel Core i7 7700HQ 2.8GHz   8GB
# 1055         14.0           Intel Atom X5-Z8350 1.44GHz   2GB
# 367          14.0            Intel Core i5 7200U 2.5GHz   8GB
# 453          15.6            Intel Core i5 7200U 2.5GHz   4GB
# 791          14.0            Intel Core i7 6600U 2.6GHz  16GB
# 542          15.6            Intel Core i7 7600U 2.8GHz   8GB
# 924          12.5              Intel Core M 6Y75 1.2GHz   8GB
# 46           13.3                  Intel Core i5 2.0GHz   8GB
# 1047         14.0            Intel Core i5 6200U 2.3GHz   8GB
# 241          15.6              Intel Core i3 6006U 2GHz   4GB
# 604          14.0           Intel Core i5 7300HQ 2.5GHz   8GB
# 84           14.0            Intel Core i5 8250U 1.6GHz   8GB
# 588          15.6            Intel Core i5 7300U 2.6GHz   8GB
# 168          15.6  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 889          15.6            Intel Core i5 7200U 2.5GHz   4GB
# 617          15.6         Intel Xeon E3-1535M v6 3.1GHz  32GB
# 1181         15.6            Intel Core i3 6006U 2.0GHz   8GB
# 923          14.0           Intel Core i5 7440HQ 2.8GHz   8GB
# 1135         13.3           Intel Atom X5-Z8350 1.44GHz   4GB
# 213          15.6            Intel Core i5 7200U 2.5GHz   8GB
# 1255         15.6            Intel Core i5 6200U 2.3GHz   4GB
# 547          13.3            Intel Core i7 8550U 1.8GHz   8GB
# 801          13.3            Intel Core i7 7500U 2.7GHz   8GB
# 1032         14.0            Intel Core i5 6200U 2.3GHz   8GB
# 669          15.6  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 51           10.1           Intel Atom x5-Z8550 1.44GHz   4GB
# 1040         14.0            Intel Core i5 7200U 2.5GHz   4GB
# 30           17.3            Intel Core i5 8250U 1.6GHz   8GB
# 424          14.0            Intel Core i7 6500U 2.5GHz   8GB
# 465          13.5            Intel Core i7 7660U 2.5GHz   8GB
# 108          14.0            Intel Core i5 7200U 2.5GHz   6GB
# 1157         15.6           Intel Core i7 7700HQ 2.8GHz   8GB
# 188          15.6            Intel Core i5 8250U 1.6GHz   8GB
# 181          18.4           Intel Core i7 6920HQ 2.9GHz  32GB
# 37           15.6            Intel Core i3 7130U 2.7GHz   4GB
# 107          13.5            Intel Core i5 7200U 2.5GHz   8GB
# 352          14.0  Intel Celeron Dual Core N3060 1.6GHz   2GB
# 437          11.6  Intel Celeron Dual Core N3060 1.6GHz   4GB
# 1254         14.0            Intel Core i7 6500U 2.5GHz   8GB
# 1191         15.6            Intel Core i5 6200U 2.3GHz   4GB
# 29           15.6            Intel Core i7 8650U 1.9GHz   8GB
# 395          14.0            Intel Core i7 7500U 2.7GHz  16GB
# 1019         14.0            Intel Core i5 6300U 2.4GHz   4GB
# 151          17.3           Intel Core i7 7700HQ 2.8GHz  16GB
#
#                                     Gpu         OpSys   Weight  Price_euros  \
# laptop_ID
# 888                Nvidia GeForce 940MX    Windows 10   1.28kg       935.00
# 863                  AMD Radeon R7 M445         Linux   2.83kg       865.00
# 1268                  Intel HD Graphics         Linux    2.2kg       324.00
# 613               Intel HD Graphics 520    Windows 10    2.2kg      1399.00
# 843               Intel HD Graphics 620    Windows 10   1.32kg      1650.00
# 728               Intel HD Graphics 520    Windows 10   1.17kg      1686.64
# 615               Intel HD Graphics 630    Windows 10      2kg      1299.00
# 1055              Intel HD Graphics 400    Windows 10   1.45kg       210.80
# 367               Intel HD Graphics 620    Windows 10      2kg       945.00
# 453               Intel HD Graphics 620         Linux    2.4kg       441.80
# 791                 Nvidia GeForce 930M    Windows 10   1.47kg      1764.00
# 542                Nvidia GeForce 930MX    Windows 10   1.93kg      1369.00
# 924               Intel HD Graphics 515    Windows 10   1.09kg      3100.00
# 46              Intel Iris Graphics 540         macOS   1.37kg      1419.00
# 1047              Intel HD Graphics 520     Windows 7   1.95kg      1195.00
# 241               Intel HD Graphics 520         Linux    2.1kg       390.00
# 604               Intel HD Graphics 630    Windows 10    1.7kg      1474.00
# 84                Intel HD Graphics 620    Windows 10   1.63kg       860.00
# 588               Intel HD Graphics 620    Windows 10    1.9kg      1008.52
# 168               Intel HD Graphics 500    Windows 10    2.1kg       348.00
# 889                Nvidia GeForce 940MX    Windows 10   2.18kg       912.50
# 617                Nvidia Quadro M2200M    Windows 10    2.5kg      4899.00
# 1181              Intel HD Graphics 520    Windows 10    2.2kg       459.00
# 923               Intel HD Graphics 620    Windows 10    1.6kg      1205.00
# 1135              Intel HD Graphics 400    Windows 10   1.35kg       196.00
# 213               Intel HD Graphics 620    Windows 10    2.2kg       597.00
# 1255              Intel HD Graphics 520     Windows 7   2.24kg       737.00
# 547              Intel UHD Graphics 620    Windows 10    1.2kg      1399.00
# 801               Intel HD Graphics 620    Windows 10   1.37kg      1970.00
# 1032              Intel HD Graphics 520    Windows 10   1.47kg      1490.00
# 669               Intel HD Graphics 500    Windows 10    2.2kg       419.00
# 51                Intel HD Graphics 400       Android   0.69kg       319.00
# 1040              Intel HD Graphics 620    Windows 10   2.31kg      1189.00
# 30                 Nvidia GeForce 930MX    Windows 10    2.5kg       896.00
# 424               Intel HD Graphics 520    Windows 10   1.43kg      1500.00
# 465        Intel Iris Plus Graphics 640  Windows 10 S   1.25kg      1799.00
# 108                Nvidia GeForce 940MX    Windows 10   1.58kg       659.00
# 1157            Nvidia GeForce GTX 1050    Windows 10    2.4kg      1142.80
# 188                Nvidia GeForce MX150         No OS   1.95kg      1199.00
# 181                  Nvidia GTX 980 SLI    Windows 10    4.4kg      2799.00
# 37                Intel HD Graphics 620         Linux    2.1kg       367.00
# 107               Intel HD Graphics 620  Windows 10 S  1.252kg      1340.00
# 352               Intel HD Graphics 400    Windows 10   1.44kg       279.00
# 437               Intel HD Graphics 400     Chrome OS   1.15kg       269.00
# 1254              Intel HD Graphics 520     Windows 7   1.54kg      2198.19
# 1191              Intel HD Graphics 520         No OS    2.1kg       398.00
# 29               Intel UHD Graphics 620    Windows 10   1.88kg      1298.00
# 395               Intel HD Graphics 620    Windows 10   1.42kg      2509.00
# 1019              Intel HD Graphics 520    Windows 10   1.48kg      1099.99
# 151             Nvidia GeForce GTX 1070    Windows 10    2.9kg      2029.00
#
#           Cpu_Company  Memory_Amount    Memory_Type  SSD
# laptop_ID
# 888             Intel            256            SSD    1
# 863             Intel           1024            HDD    0
# 1268            Intel            500            HDD    0
# 613             Intel            256            SSD    1
# 843             Intel            256            SSD    1
# 728             Intel            512            SSD    1
# 615             Intel            256            SSD    1
# 1055            Intel             32  Flash Storage    0
# 367             Intel            256            SSD    1
# 453             Intel            500            HDD    0
# 791             Intel            512            SSD    1
# 542             Intel            256            SSD    1
# 924             Intel            240            SSD    1
# 46              Intel            256            SSD    1
# 1047            Intel            256            SSD    1
# 241             Intel           1024            HDD    0
# 604             Intel            256            SSD    1
# 84              Intel            256            SSD    1
# 588             Intel            500            HDD    0
# 168             Intel           1024            HDD    0
# 889             Intel           1152       SSD, HDD    0
# 617             Intel           1024            SSD    1
# 1181            Intel           1024            HDD    0
# 923             Intel            256            SSD    1
# 1135            Intel             32  Flash Storage    0
# 213             Intel            256            SSD    1
# 1255            Intel            500            HDD    0
# 547             Intel            256            SSD    1
# 801             Intel            512            SSD    1
# 1032            Intel            256            SSD    1
# 669             Intel            500            HDD    0
# 51              Intel             64  Flash Storage    0
# 1040            Intel            500            HDD    0
# 30              Intel           1024            HDD    0
# 424             Intel            256            SSD    1
# 465             Intel            256            SSD    1
# 108             Intel            256            SSD    1
# 1157            Intel           1152       SSD, HDD    0
# 188             Intel            256            SSD    1
# 181             Intel           1536       SSD, HDD    0
# 37              Intel           1024            HDD    0
# 107             Intel            256            SSD    1
# 352             Intel             32  Flash Storage    0
# 437             Intel             16  Flash Storage    0
# 1254            Intel            256            SSD    1
# 1191            Intel            500            HDD    0
# 29              Intel            512       SSD, SSD    0
# 395             Intel            512            SSD    1
# 1019            Intel            256            SSD    1
# 151             Intel           1280       SSD, HDD    0

# %%
df['Weight'] = df['Weight'].replace('kg','').astype('float')
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df['Weight'] = df['Weight'].replace('kg','').astype('float')
#       2 df.sample(5)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
#     447 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 448     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353 except (TypeError, NotImplementedError):
#     354     if not ignore_failures:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:526, in Block.astype(self, dtype, copy, errors)
#     508 """
#     509 Coerce to the new dtype.
#     510
#    (...)
#     522 Block
#     523 """
#     524 values = self.values
# --> 526 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     528 new_values = maybe_coerce_values(new_values)
#     529 newb = self.make_block(new_values)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:299, in astype_array_safe(values, dtype, copy, errors)
#     296     return values.copy()
#     298 try:
# --> 299     new_values = astype_array(values, dtype, copy=copy)
#     300 except (ValueError, TypeError):
#     301     # e.g. astype_nansafe can fail on object-dtype of strings
#     302     #  trying to convert to float
#     303     if errors == "ignore":
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:230, in astype_array(values, dtype, copy)
#     227     values = values.astype(dtype, copy=copy)
#     229 else:
# --> 230     values = astype_nansafe(values, dtype, copy=copy)
#     232 # in pandas we don't store numpy str dtypes, so convert to object
#     233 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\dtypes\astype.py:170, in astype_nansafe(arr, dtype, copy, skipna)
#     166     raise ValueError(msg)
#     168 if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#     169     # Explicit copy, or required since NumPy can't view from / to object.
# --> 170     return arr.astype(dtype, copy=True)
#     172 return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: '1.37kg'

# %%
df.dtypes

# %% [markdown]
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]})

# %%
clients = clients.set_index('laptop_id')

# %%
df1 = df.join(clients, how = 'outer')
df1.sample(10)
# Out:
#      Company                                    Product     TypeName  Inches  \
# 351   Lenovo                         Legion Y520-15IKBN       Gaming    15.6
# 294   Lenovo                          IdeaPad 320-15IKB     Notebook    15.6
# 865     Asus  K556UR-DM621T (i7-7500U/8GB/256GB/GeForce     Notebook    15.6
# 854       HP                              EliteBook 840    Ultrabook    14.0
# 21      Asus                            Vivobook E200HA      Netbook    11.6
# 120     Dell                              Inspiron 7570     Notebook    15.6
# 493     Dell                             Precision 3520  Workstation    15.6
# 1119  Lenovo                         Legion Y520-15IKBN       Gaming    15.6
# 25        HP    15-BS101nv (i7-8550U/8GB/256GB/FHD/W10)    Ultrabook    15.6
# 306     Asus                         Rog GL702VS-GC095T       Gaming    17.3
#
#                               Cpu   Ram                         Gpu  \
# 351   Intel Core i7 7700HQ 2.8GHz  16GB  Nvidia GeForce GTX 1050 Ti
# 294    Intel Core i7 7500U 2.7GHz   8GB        Nvidia GeForce 940MX
# 865    Intel Core i7 7500U 2.7GHz   8GB    Nvidia GeForce GTX 930MX
# 854    Intel Core i7 6500U 2.5GHz   8GB       Intel HD Graphics 520
# 21    Intel Atom x5-Z8350 1.44GHz   2GB       Intel HD Graphics 400
# 120    Intel Core i7 8550U 1.8GHz   8GB        Nvidia GeForce 940MX
# 493   Intel Core i7 6820HQ 2.7GHz  16GB          Nvidia Quadro M620
# 1119  Intel Core i7 7700HQ 2.8GHz  16GB  Nvidia GeForce GTX 1050 Ti
# 25     Intel Core i7 8550U 1.8GHz   8GB       Intel HD Graphics 620
# 306   Intel Core i7 7700HQ 2.8GHz  16GB     Nvidia GeForce GTX 1070
#
#            OpSys  Weight  Price_euros Cpu_Company  Memory_Amount  \
# 351   Windows 10   2.4kg      1129.00       Intel         2304.0
# 294        No OS   2.2kg       659.01       Intel         1024.0
# 865   Windows 10   2.3kg       787.00       Intel          256.0
# 854    Windows 7  1.54kg      1870.00       Intel          512.0
# 21    Windows 10  0.98kg       191.90       Intel           32.0
# 120   Windows 10  2.16kg      1130.33       Intel         1280.0
# 493   Windows 10  2.17kg      2338.00       Intel          512.0
# 1119  Windows 10   2.4kg      1199.00       Intel          512.0
# 25    Windows 10  1.91kg       659.00       Intel          256.0
# 306   Windows 10   2.9kg      2122.00       Intel         1280.0
#
#         Memory_Type  SSD  client_id
# 351        SSD, HDD  0.0        NaN
# 294             HDD  0.0        NaN
# 865             SSD  1.0        NaN
# 854             SSD  1.0        NaN
# 21    Flash Storage  0.0        NaN
# 120        SSD, HDD  0.0       33.0
# 493             SSD  1.0        NaN
# 1119            SSD  1.0        NaN
# 25              SSD  1.0        NaN
# 306        SSD, HDD  0.0        NaN

# %%
df1.loc[[506, 398, 710, 120, 1999]]
# Out:
#      Company            Product  TypeName  Inches  \
# 506   Lenovo      ThinkPad L570  Notebook    15.6
# 398      NaN                NaN       NaN     NaN
# 710   Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120     Dell      Inspiron 7570  Notebook    15.6
# 1999     NaN                NaN       NaN     NaN
#
#                               Cpu  Ram                    Gpu       OpSys  \
# 506    Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10
# 398                           NaN  NaN                    NaN         NaN
# 710   AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 120    Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
# 1999                          NaN  NaN                    NaN         NaN
#
#       Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD  \
# 506    2.3kg       911.00       Intel          256.0         SSD  1.0
# 398      NaN          NaN         NaN            NaN         NaN  NaN
# 710    2.2kg       429.00         AMD         1024.0         HDD  0.0
# 120   2.16kg      1130.33       Intel         1280.0    SSD, HDD  0.0
# 1999     NaN          NaN         NaN            NaN         NaN  NaN
#
#       client_id
# 506        45.0
# 398        32.0
# 710        67.0
# 120        33.0
# 1999       43.0

# %%
df2 = clients.merge(df,left_on = 'laptop_id', right_on = 'laptop_ID')

# %%
df2

# %% [markdown]
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей
# 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.groupby('Company').agg({'Price_euros':'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %%
df.groupby('Cpu_Company').agg({'Price_euros':['min','mean','max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %%
df.pivot_table(index = 'Cpu_Company',
              columns = 'Ram',
              values = 'Price_euros',
              aggfunc = 'count',
              fill_value = 0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %%
df.pivot_table(index = 'OpSys',
              columns = 'Memory_Amount',
              values = 'Price_euros',
              aggfunc = 'mean',
              fill_value = 0)
# Out:
# Memory_Amount  8       16          32          64           128     180   \
# OpSys
# Android           0    0.00    0.000000  434.000000     0.000000     0.0
# Chrome OS         0  305.38  412.454545  774.333333  1275.000000     0.0
# Linux             0    0.00    0.000000    0.000000   490.500000     0.0
# Mac OS X          0    0.00    0.000000    0.000000  1099.000000     0.0
# No OS             0    0.00    0.000000    0.000000   362.024000     0.0
# Windows 10     2249    0.00  270.001471  333.795556   673.385692  1073.5
# Windows 10 S      0    0.00    0.000000  308.995000  1039.000000     0.0
# Windows 7         0    0.00    0.000000    0.000000  1320.323333  1199.0
# macOS             0    0.00    0.000000    0.000000  1119.315000     0.0
#
# Memory_Amount  240          256         500   508   ...     768          1024  \
# OpSys                                               ...
# Android           0     0.000000    0.000000     0  ...     0.00     0.000000
# Chrome OS         0  1559.000000    0.000000     0  ...     0.00     0.000000
# Linux             0   795.814000  389.056364     0  ...     0.00   581.401290
# Mac OS X          0  1311.994000    0.000000     0  ...     0.00     0.000000
# No OS             0   754.834615  404.675385     0  ...     0.00   540.539600
# Windows 10     3100  1214.518551  664.717647     0  ...  1607.96   880.695661
# Windows 10 S      0  1668.950000    0.000000     0  ...     0.00     0.000000
# Windows 7         0  1846.466800  924.048333  1002  ...     0.00  1539.666667
# macOS             0  1600.370000    0.000000     0  ...     0.00     0.000000
#
# Memory_Amount  1088         1152         1280         1536         2048  \
# OpSys
# Android           0     0.000000     0.000000     0.000000     0.000000
# Chrome OS         0     0.000000     0.000000     0.000000     0.000000
# Linux             0   994.000000     0.000000     0.000000     0.000000
# Mac OS X          0     0.000000     0.000000     0.000000     0.000000
# No OS             0   895.666667  1149.000000     0.000000   594.000000
# Windows 10     1993  1285.464494  1878.083562  2549.750667  1058.201333
# Windows 10 S      0     0.000000     0.000000     0.000000     0.000000
# Windows 7         0     0.000000     0.000000     0.000000     0.000000
# macOS             0     0.000000     0.000000     0.000000     0.000000
#
# Memory_Amount    2176         2304  2560
# OpSys
# Android          0.00     0.000000     0
# Chrome OS        0.00     0.000000     0
# Linux            0.00  1049.000000     0
# Mac OS X         0.00     0.000000     0
# No OS            0.00     0.000000     0
# Windows 10     977.95  1590.015556  1849
# Windows 10 S     0.00     0.000000     0
# Windows 7        0.00     0.000000     0
# macOS            0.00     0.000000     0
#
# [9 rows x 22 columns]

# %%
df.groupby(['OpSys','Memory_Amount']).agg({'Price_euros':'mean'}).unstack('Memory_Amount').fillna(0)
# Out:
#               Price_euros                                               \
# Memory_Amount        8       16          32          64           128
# OpSys
# Android               0.0    0.00    0.000000  434.000000     0.000000
# Chrome OS             0.0  305.38  412.454545  774.333333  1275.000000
# Linux                 0.0    0.00    0.000000    0.000000   490.500000
# Mac OS X              0.0    0.00    0.000000    0.000000  1099.000000
# No OS                 0.0    0.00    0.000000    0.000000   362.024000
# Windows 10         2249.0    0.00  270.001471  333.795556   673.385692
# Windows 10 S          0.0    0.00    0.000000  308.995000  1039.000000
# Windows 7             0.0    0.00    0.000000    0.000000  1320.323333
# macOS                 0.0    0.00    0.000000    0.000000  1119.315000
#
#                                                                 ...           \
# Memory_Amount    180     240          256         500     508   ...     768
# OpSys                                                           ...
# Android           0.0     0.0     0.000000    0.000000     0.0  ...     0.00
# Chrome OS         0.0     0.0  1559.000000    0.000000     0.0  ...     0.00
# Linux             0.0     0.0   795.814000  389.056364     0.0  ...     0.00
# Mac OS X          0.0     0.0  1311.994000    0.000000     0.0  ...     0.00
# No OS             0.0     0.0   754.834615  404.675385     0.0  ...     0.00
# Windows 10     1073.5  3100.0  1214.518551  664.717647     0.0  ...  1607.96
# Windows 10 S      0.0     0.0  1668.950000    0.000000     0.0  ...     0.00
# Windows 7      1199.0     0.0  1846.466800  924.048333  1002.0  ...     0.00
# macOS             0.0     0.0  1600.370000    0.000000     0.0  ...     0.00
#
#                                                                            \
# Memory_Amount         1024    1088         1152         1280         1536
# OpSys
# Android           0.000000     0.0     0.000000     0.000000     0.000000
# Chrome OS         0.000000     0.0     0.000000     0.000000     0.000000
# Linux           581.401290     0.0   994.000000     0.000000     0.000000
# Mac OS X          0.000000     0.0     0.000000     0.000000     0.000000
# No OS           540.539600     0.0   895.666667  1149.000000     0.000000
# Windows 10      880.695661  1993.0  1285.464494  1878.083562  2549.750667
# Windows 10 S      0.000000     0.0     0.000000     0.000000     0.000000
# Windows 7      1539.666667     0.0     0.000000     0.000000     0.000000
# macOS             0.000000     0.0     0.000000     0.000000     0.000000
#
#
# Memory_Amount         2048    2176         2304    2560
# OpSys
# Android           0.000000    0.00     0.000000     0.0
# Chrome OS         0.000000    0.00     0.000000     0.0
# Linux             0.000000    0.00  1049.000000     0.0
# Mac OS X          0.000000    0.00     0.000000     0.0
# No OS           594.000000    0.00     0.000000     0.0
# Windows 10     1058.201333  977.95  1590.015556  1849.0
# Windows 10 S      0.000000    0.00     0.000000     0.0
# Windows 7         0.000000    0.00     0.000000     0.0
# macOS             0.000000    0.00     0.000000     0.0
#
# [9 rows x 22 columns]

# %% [markdown]
# 5.1 Ноутбуков каких компаний и с каким процессором больше?
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index = df.Company,
           columns = df.Cpu_Company)
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
pd.crosstab(index = df.Memory_Type,
           columns = df.Memory_Amount)
