# %%
import pandas as pd

# %%
df = pd.read_csv('laptop_price.csv',encoding='cp1251', index_col = 'laptop_ID')

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# 1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)
# 1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
# 1.4 Удалите признаки Memory и ScreenResolution

# %%
df['Cpu_Company']=df.Cpu.apply(lambda x: x.split()[0])

# %%
df.sample(5)
# Out:
#           Company                                Product  TypeName  Inches
# laptop_ID
# 387        Lenovo  V310-15ISK (i3-6006U/4GB/128GB/FHD/No  Notebook    15.6  \
# 139        Lenovo           V110-15IAP (N3350/4GB/1TB/No  Notebook    15.6
# 623          Dell                            Vostro 3568  Notebook    15.6
# 632        Lenovo                      IdeaPad 320-15IKB  Notebook    15.6
# 408          Asus     FX753VD-GC461T (i7-7700HQ/16GB/1TB    Gaming    17.3
#
#             ScreenResolution                                   Cpu   Ram
# laptop_ID
# 387        Full HD 1920x1080              Intel Core i3 6006U 2GHz   4GB  \
# 139                 1366x768  Intel Celeron Dual Core N3350 1.1GHz   4GB
# 623        Full HD 1920x1080            Intel Core i5 7200U 2.5GHz   4GB
# 632        Full HD 1920x1080            Intel Core i7 7500U 2.7GHz   8GB
# 408        Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz  16GB
#
#                          Memory                      Gpu       OpSys  Weight
# laptop_ID
# 387                   128GB SSD    Intel HD Graphics 520       No OS  1.85kg  \
# 139                     1TB HDD    Intel HD Graphics 500       No OS   1.9kg
# 623                   128GB SSD       AMD Radeon R5 M420       Linux  2.18kg
# 632                     1TB HDD     Nvidia GeForce 920MX  Windows 10   2.2kg
# 408        256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10   2.9kg
#
#            Price_euros Cpu_Company Memory_Amount
# laptop_ID
# 387             403.50       Intel           128
# 139             252.36       Intel           1TB
# 623             569.00       Intel           128
# 632             899.00       Intel           1TB
# 408            1529.00       Intel           256

# %% [markdown]
# 256GB SSD + 1TB HDD

# %%
def func(lst):
    sum_GB = 0 
    for el in lst.split():
        if 'GB' in el:
            sum_GB += float(el[:-2])
        elif 'TB' in el:
            sum_GB += float(el[:-2]) * 1024
    return int(sum_GB)

df['Memory_Amount'] = df.Memory.apply(func)
df.sample(10)
# Out:
#           Company                 Product            TypeName  Inches
# laptop_ID
# 170          Acer                Aspire 3            Notebook    15.6  \
# 646        Lenovo           Thinkpad Yoga  2 in 1 Convertible    13.3
# 1036           HP       Spectre 13-V100nv            Notebook    13.3
# 220          Dell           Inspiron 5370           Ultrabook    13.3
# 55           Acer                Aspire 3            Notebook    15.6
# 933           MSI               GL62M 7RD              Gaming    15.6
# 327          Asus  ZenBook UX410UA-GV183T            Notebook    14.0
# 753          Acer           Chromebook 14            Notebook    14.0
# 269          Dell           Inspiron 3567            Notebook    15.6
# 625           MSI              GT62VR 7RE              Gaming    15.6
#
#                                     ScreenResolution
# laptop_ID
# 170                                         1366x768  \
# 646        IPS Panel Full HD / Touchscreen 1920x1080
# 1036                     IPS Panel Full HD 1920x1080
# 220                      IPS Panel Full HD 1920x1080
# 55                                          1366x768
# 933                                Full HD 1920x1080
# 327                                Full HD 1920x1080
# 753                                         1366x768
# 269                                Full HD 1920x1080
# 625                                Full HD 1920x1080
#
#                                             Cpu   Ram                Memory
# laptop_ID
# 170        Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD  \
# 646                  Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1036                 Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 220                  Intel Core i7 8550U 1.8GHz   8GB             256GB SSD
# 55                   Intel Core i3 7100U 2.4GHz   4GB               1TB HDD
# 933                 Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 327                  Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 753        Intel Celeron Dual Core N3060 1.6GHz   2GB    32GB Flash Storage
# 269                  Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 625                 Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 170          Intel HD Graphics 505  Windows 10   2.1kg       363.51  \
# 646          Intel HD Graphics 620  Windows 10  1.37kg      1757.42
# 1036         Intel HD Graphics 620  Windows 10  1.11kg      1149.00
# 220                 AMD Radeon 530  Windows 10   1.4kg       931.88
# 55           Intel HD Graphics 620  Windows 10   2.4kg       384.00
# 933        Nvidia GeForce GTX 1050  Windows 10   2.2kg      1119.91
# 327          Intel HD Graphics 620  Windows 10     2kg      1094.00
# 753          Intel HD Graphics 400   Chrome OS  1.68kg       330.00
# 269             AMD Radeon R5 M430  Windows 10  2.24kg       565.00
# 625        Nvidia GeForce GTX 1070  Windows 10  2.94kg      2267.86
#
#           Cpu_Company  Memory_Amount
# laptop_ID
# 170             Intel           1024
# 646             Intel            256
# 1036            Intel            256
# 220             Intel            256
# 55              Intel           1024
# 933             Intel           1152
# 327             Intel            256
# 753             Intel             32
# 269             Intel           1024
# 625             Intel           1280

# %% [markdown]
# 1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
# 1.4 Удалите признаки Memory и ScreenResolution
#
#  256GB SSD + 1TB HDD

# %%
def func1(lst):
    new_l = ''
    s = lst.split()
    for el in s:
        if el.isalpha():
            if new_l:
                if new_l[-1] == 'D' or new_l[-1] == 'e':
                    new_l += ', '
                else:
                    new_l += ' '
            new_l += el
    return new_l
func1('256GB SSD + 1TB HDD')
# Out:
# 'SSD, HDD'

# %%
df['Memory_Type'] = df.Memory.apply(func1)
df.sample(50)
# Out:
#              Company                                  Product
# laptop_ID
# 752           Lenovo                            Thinkpad P51s  \
# 1213              HP                           Pavilion Power
# 1067              HP                              ProBook 450
# 826               HP                            Chromebook 11
# 1189              HP                              ProBook 450
# 421             Asus                             ZenBook Flip
# 726         Mediacom                            Smartbook 142
# 1155              HP                            EliteBook 850
# 274           Lenovo  V330-15IKB (i7-8550U/8GB/256GB/FHD/W10)
# 918               HP                            Elitebook 820
# 359               HP                                 Zbook 15
# 750          Toshiba                          Tecra X40-D-10G
# 1281            Acer                           Aspire ES1-531
# 998          Toshiba                          Tecra A40-C-1KF
# 781          Toshiba                          Tecra A40-C-1E5
# 507             Asus                          VivoBook E201NA
# 727               HP                              ProBook 470
# 2              Apple                              Macbook Air
# 1044              HP                              ProBook 440
# 238             Dell                              Vostro 5468
# 967             Asus                          Chromebook Flip
# 565               HP   15-bw007nv (A10-9620P/6GB/128GB/Radeon
# 142               HP                          Envy 13-AD007nv
# 1059              HP                            EliteBook 850
# 1040              HP                              ProBook 650
# 793           Lenovo                           ThinkPad T470s
# 352               HP                        Stream 14-AX001nv
# 623             Dell                              Vostro 3568
# 221           Lenovo                        IdeaPad 320-17IKB
# 8              Apple                              Macbook Air
# 991             Asus        Q534UX-BHI7T19 (i7-7500U/16GB/2TB
# 501             Asus                         Rog G752VL-UH71T
# 1056         Toshiba                          Tecra A50-C-218
# 1242            Dell                            Inspiron 5578
# 333             Asus                             VivoBook S15
# 876               HP                              Probook 450
# 1111            Dell                            Inspiron 5567
# 402               HP     15-BW004nv (A9-9420/4GB/256GB/Radeon
# 302             Dell                           Precision 7720
# 107        Microsoft                           Surface Laptop
# 484           Lenovo                            Thinkpad T470
# 806             Dell                            Latitude 3580
# 1129          Lenovo                                Yoga Book
# 11                HP                                   250 G6
# 140             Asus        FX753VD-GC086T (i5-7300HQ/8GB/1TB
# 470           Lenovo                       IdeaPad 510s-14IKB
# 959           Lenovo                       IdeaPad Y700-15ACZ
# 758               HP                                 Zbook 17
# 1205            Acer                           Aspire E5-576G
# 1264            Dell                            Latitude 5480
#
#                      TypeName  Inches
# laptop_ID
# 752               Workstation    15.6  \
# 1213                 Notebook    15.6
# 1067                 Notebook    15.6
# 826                   Netbook    11.6
# 1189                 Notebook    15.6
# 421        2 in 1 Convertible    13.3
# 726                  Notebook    14.0
# 1155                Ultrabook    15.6
# 274                  Notebook    15.6
# 918                   Netbook    12.5
# 359               Workstation    15.6
# 750                  Notebook    14.0
# 1281                 Notebook    15.6
# 998                  Notebook    14.0
# 781                  Notebook    14.0
# 507                   Netbook    11.6
# 727                  Notebook    17.3
# 2                   Ultrabook    13.3
# 1044                 Notebook    14.0
# 238                  Notebook    14.0
# 967        2 in 1 Convertible    12.5
# 565                  Notebook    15.6
# 142                  Notebook    13.3
# 1059                 Notebook    15.6
# 1040                 Notebook    14.0
# 793                 Ultrabook    14.0
# 352                  Notebook    14.0
# 623                  Notebook    15.6
# 221                  Notebook    17.3
# 8                   Ultrabook    13.3
# 991        2 in 1 Convertible    15.6
# 501                    Gaming    17.3
# 1056                 Notebook    15.6
# 1242       2 in 1 Convertible    15.0
# 333                 Ultrabook    15.6
# 876                  Notebook    15.6
# 1111                 Notebook    15.6
# 402                 Ultrabook    15.6
# 302               Workstation    17.3
# 107                 Ultrabook    13.5
# 484                  Notebook    14.0
# 806                  Notebook    15.6
# 1129       2 in 1 Convertible    10.1
# 11                   Notebook    15.6
# 140                    Gaming    17.3
# 470                  Notebook    14.0
# 959                    Gaming    15.6
# 758               Workstation    17.3
# 1205                 Notebook    15.6
# 1264                 Notebook    14.0
#
#                                     ScreenResolution
# laptop_ID
# 752                  IPS Panel 4K Ultra HD 3840x2160  \
# 1213                     IPS Panel Full HD 1920x1080
# 1067                                        1366x768
# 826                                         1366x768
# 1189                               Full HD 1920x1080
# 421        IPS Panel Full HD / Touchscreen 1920x1080
# 726                      IPS Panel Full HD 1920x1200
# 1155                               Full HD 1920x1080
# 274                                Full HD 1920x1080
# 918                                Full HD 1920x1080
# 359                                Full HD 1920x1080
# 750        IPS Panel Full HD / Touchscreen 1920x1080
# 1281                                        1366x768
# 998                                         1366x768
# 781                               IPS Panel 1366x768
# 507                                         1366x768
# 727                                Full HD 1920x1080
# 2                                           1440x900
# 1044                                        1366x768
# 238                                Full HD 1920x1080
# 967                                Full HD 1920x1080
# 565                      IPS Panel Full HD 1920x1080
# 142                      IPS Panel Full HD 1920x1080
# 1059                               Full HD 1920x1080
# 1040                                        1366x768
# 793                                Full HD 1920x1080
# 352                                         1366x768
# 623                                Full HD 1920x1080
# 221                                         1600x900
# 8                                           1440x900
# 991              4K Ultra HD / Touchscreen 3840x2160
# 501        IPS Panel Full HD / Touchscreen 1920x1080
# 1056                     IPS Panel Full HD 1920x1080
# 1242                 Full HD / Touchscreen 1920x1080
# 333                                Full HD 1920x1080
# 876                                Full HD 1920x1080
# 1111                               Full HD 1920x1080
# 402                                Full HD 1920x1080
# 302                                Full HD 1920x1080
# 107                            Touchscreen 2256x1504
# 484                                Full HD 1920x1080
# 806                                         1366x768
# 1129                 IPS Panel Touchscreen 1920x1200
# 11                                          1366x768
# 140                                Full HD 1920x1080
# 470                      IPS Panel Full HD 1920x1080
# 959                      IPS Panel Full HD 1920x1080
# 758                      IPS Panel Full HD 1920x1080
# 1205                               Full HD 1920x1080
# 1264                                        1366x768
#
#                                             Cpu   Ram                  Memory
# laptop_ID
# 752                  Intel Core i7 7600U 2.8GHz  16GB                 1TB SSD  \
# 1213                Intel Core i7 7700HQ 2.8GHz  12GB    128GB SSD +  1TB HDD
# 1067                 Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# 826        Intel Celeron Dual Core N3060 1.6GHz   4GB      16GB Flash Storage
# 1189                 Intel Core i7 8550U 1.8GHz  16GB               512GB SSD
# 421                  Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 726                    Intel Atom Z8350 1.92GHz   4GB                32GB HDD
# 1155                 Intel Core i7 6500U 2.5GHz   8GB               256GB SSD
# 274                  Intel Core i7 8550U 1.8GHz   8GB               256GB SSD
# 918                  Intel Core i7 7500U 2.7GHz   8GB               512GB SSD
# 359                 Intel Core i7 7700HQ 2.8GHz   8GB               256GB SSD
# 750                  Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 1281       Intel Celeron Dual Core N3060 1.6GHz   4GB               500GB HDD
# 998                  Intel Core i5 6200U 2.3GHz   4GB               500GB HDD
# 781                  Intel Core i5 6200U 2.3GHz   4GB               128GB SSD
# 507        Intel Celeron Dual Core N3350 1.1GHz   4GB      64GB Flash Storage
# 727                  Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 2                          Intel Core i5 1.8GHz   8GB     128GB Flash Storage
# 1044                 Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# 238                  Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 967                 Intel Core M M7-6Y75 1.2GHz   8GB      64GB Flash Storage
# 565             AMD A10-Series A10-9620P 2.5GHz   6GB               128GB SSD
# 142                  Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# 1059                 Intel Core i5 6300U 2.4GHz   8GB  256GB SSD +  500GB HDD
# 1040                 Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 793                  Intel Core i7 7500U 2.7GHz  16GB               512GB SSD
# 352        Intel Celeron Dual Core N3060 1.6GHz   2GB      32GB Flash Storage
# 623                  Intel Core i5 7200U 2.5GHz   4GB               128GB SSD
# 221                  Intel Core i5 7200U 2.5GHz   8GB                 1TB HDD
# 8                          Intel Core i5 1.8GHz   8GB     256GB Flash Storage
# 991                  Intel Core i7 7500U 2.7GHz  16GB    512GB SSD +  2TB HDD
# 501                 Intel Core i7 6700HQ 2.6GHz  24GB    256GB SSD +  1TB HDD
# 1056                 Intel Core i7 6500U 2.5GHz  16GB               256GB SSD
# 1242                 Intel Core i3 7100U 2.4GHz   4GB               500GB HDD
# 333                  Intel Core i7 7500U 2.7GHz   8GB               256GB SSD
# 876                  Intel Core i5 6200U 2.3GHz   4GB               500GB HDD
# 1111                 Intel Core i5 7200U 2.5GHz   8GB                 1TB HDD
# 402                     AMD A9-Series 9420 3GHz   4GB               256GB SSD
# 302                 Intel Core i7 7820HQ 2.9GHz  16GB               256GB SSD
# 107                  Intel Core i5 7200U 2.5GHz   8GB               256GB SSD
# 484                  Intel Core i5 7200U 2.5GHz   8GB               180GB SSD
# 806                  Intel Core i5 7200U 2.5GHz   8GB               128GB SSD
# 1129                Intel Atom x5-Z8550 1.44GHz   4GB      64GB Flash Storage
# 11                   Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
# 140                 Intel Core i5 7300HQ 2.5GHz   8GB    128GB SSD +  1TB HDD
# 470                  Intel Core i7 7500U 2.7GHz   8GB               512GB SSD
# 959                         AMD FX 8800P 2.1GHz  16GB    512GB SSD +  1TB HDD
# 758               Intel Xeon E3-1535M v5 2.9GHz  16GB               256GB SSD
# 1205                 Intel Core i5 7200U 2.5GHz   4GB               256GB SSD
# 1264                 Intel Core i5 7200U 2.5GHz   4GB               500GB HDD
#
#                                 Gpu         OpSys   Weight  Price_euros
# laptop_ID
# 752             Nvidia Quadro M520M    Windows 10    2.5kg      3299.00  \
# 1213        Nvidia GeForce GTX 1050    Windows 10   2.21kg      1327.00
# 1067          Intel HD Graphics 620    Windows 10   2.04kg       979.00
# 826           Intel HD Graphics 400     Chrome OS   1.23kg       385.00
# 1189         Intel UHD Graphics 620    Windows 10    2.1kg      1159.00
# 421           Intel HD Graphics 620    Windows 10   1.27kg       928.00
# 726           Intel HD Graphics 400    Windows 10    1.4kg       265.00
# 1155          Intel HD Graphics 520     Windows 7   1.88kg      2171.72
# 274          Intel UHD Graphics 620    Windows 10   2.05kg       880.00
# 918           Intel HD Graphics 620    Windows 10   1.26kg      1483.00
# 359             Nvidia Quadro M1200    Windows 10    2.6kg      1738.27
# 750           Intel HD Graphics 620    Windows 10   1.25kg      1535.00
# 1281          Intel HD Graphics 400         Linux    2.4kg       289.00
# 998           Intel HD Graphics 520    Windows 10   1.75kg       915.00
# 781           Intel HD Graphics 520    Windows 10   1.75kg      1020.00
# 507           Intel HD Graphics 500  Windows 10 S    1.2kg       340.00
# 727            Nvidia GeForce 930MX    Windows 10   2.63kg      1200.00
# 2            Intel HD Graphics 6000         macOS   1.34kg       898.94
# 1044          Intel HD Graphics 620    Windows 10   1.64kg       973.00
# 238           Intel HD Graphics 620    Windows 10    1.6kg       859.00
# 967           Intel HD Graphics 515     Chrome OS    1.2kg      1159.00
# 565                  AMD Radeon 530    Windows 10   1.91kg       568.90
# 142           Intel HD Graphics 620    Windows 10   1.32kg       699.00
# 1059          Intel HD Graphics 520    Windows 10   1.84kg      2103.34
# 1040          Intel HD Graphics 620    Windows 10   2.31kg      1189.00
# 793           Intel HD Graphics 620    Windows 10    1.7kg      2299.00
# 352           Intel HD Graphics 400    Windows 10   1.44kg       279.00
# 623              AMD Radeon R5 M420         Linux   2.18kg       569.00
# 221        Nvidia GeForce GTX 940MX         No OS    2.8kg       589.00
# 8            Intel HD Graphics 6000         macOS   1.34kg      1158.70
# 991         Nvidia GeForce GTX 950M    Windows 10    2.3kg      1799.00
# 501         Nvidia GeForce GTX 965M    Windows 10   4.33kg      1269.00
# 1056            Nvidia GeForce 930M    Windows 10    2.4kg      1425.00
# 1242          Intel HD Graphics 620    Windows 10   2.08kg       509.00
# 333            Nvidia GeForce 940MX    Windows 10    1.7kg      1049.90
# 876           Intel HD Graphics 520    Windows 10   2.07kg       910.00
# 1111             AMD Radeon R7 M445    Windows 10   2.36kg       638.80
# 402                  AMD Radeon 520    Windows 10   1.91kg       499.00
# 302             Nvidia Quadro M1200    Windows 10   3.42kg      2884.86
# 107           Intel HD Graphics 620  Windows 10 S  1.252kg      1340.00
# 484           Intel HD Graphics 620    Windows 10    1.7kg      1364.00
# 806           Intel HD Graphics 620    Windows 10   1.95kg       810.00
# 1129          Intel HD Graphics 400       Android   0.69kg       549.00
# 11            Intel HD Graphics 620         No OS   1.86kg       393.90
# 140         Nvidia GeForce GTX 1050    Windows 10      3kg       938.00
# 470              AMD Radeon R7 M460         No OS    1.5kg       799.00
# 959              AMD Radeon R9 M385    Windows 10    2.5kg       999.00
# 758            Nvidia Quadro M2000M     Windows 7      3kg      4389.00
# 1205           Nvidia GeForce 940MX    Windows 10   2.23kg       691.00
# 1264          Intel HD Graphics 620    Windows 10    1.6kg       875.00
#
#           Cpu_Company  Memory_Amount    Memory_Type
# laptop_ID
# 752             Intel           1024            SSD
# 1213            Intel           1152       SSD, HDD
# 1067            Intel            256            SSD
# 826             Intel             16  Flash Storage
# 1189            Intel            512            SSD
# 421             Intel            256            SSD
# 726             Intel             32            HDD
# 1155            Intel            256            SSD
# 274             Intel            256            SSD
# 918             Intel            512            SSD
# 359             Intel            256            SSD
# 750             Intel            256            SSD
# 1281            Intel            500            HDD
# 998             Intel            500            HDD
# 781             Intel            128            SSD
# 507             Intel             64  Flash Storage
# 727             Intel            256            SSD
# 2               Intel            128  Flash Storage
# 1044            Intel            256            SSD
# 238             Intel            256            SSD
# 967             Intel             64  Flash Storage
# 565               AMD            128            SSD
# 142             Intel            256            SSD
# 1059            Intel            756       SSD, HDD
# 1040            Intel            500            HDD
# 793             Intel            512            SSD
# 352             Intel             32  Flash Storage
# 623             Intel            128            SSD
# 221             Intel           1024            HDD
# 8               Intel            256  Flash Storage
# 991             Intel           2560       SSD, HDD
# 501             Intel           1280       SSD, HDD
# 1056            Intel            256            SSD
# 1242            Intel            500            HDD
# 333             Intel            256            SSD
# 876             Intel            500            HDD
# 1111            Intel           1024            HDD
# 402               AMD            256            SSD
# 302             Intel            256            SSD
# 107             Intel            256            SSD
# 484             Intel            180            SSD
# 806             Intel            128            SSD
# 1129            Intel             64  Flash Storage
# 11              Intel            500            HDD
# 140             Intel           1152       SSD, HDD
# 470             Intel            512            SSD
# 959               AMD           1536       SSD, HDD
# 758             Intel            256            SSD
# 1205            Intel            256            SSD
# 1264            Intel            500            HDD

# %%
df.drop(columns = ['Memory','ScreenResolution'], inplace = True)
df.head(3)
# Out:
#           Company      Product   TypeName  Inches                         Cpu
# laptop_ID
# 1           Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz  \
# 2           Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz
# 3              HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz
#
#            Ram                           Gpu  OpSys  Weight  Price_euros
# laptop_ID
# 1          8GB  Intel Iris Plus Graphics 640  macOS  1.37kg      1339.69  \
# 2          8GB        Intel HD Graphics 6000  macOS  1.34kg       898.94
# 3          8GB         Intel HD Graphics 620  No OS  1.86kg       575.00
#
#           Cpu_Company  Memory_Amount    Memory_Type
# laptop_ID
# 1               Intel            128            SSD
# 2               Intel            128  Flash Storage
# 3               Intel            256            SSD

# %% [markdown]
# 2.1 Создайте признак SSD, который изначально равен 0
# 2.2 Поставьте в признаке SSD 1, если ноутбук действительно с типом носителя SSD
# 2.3 Уберите в признаке Weight значения 'kg' и поменяйте его тип данных на вещественный

# %%
df.Memory_Type.value_counts()
# Out:
# Memory_Type
# SSD                   637
# HDD                   374
# SSD, HDD              200
# Flash Storage          74
# Hybrid                 10
# SSD, SSD                4
# SSD, Hybrid             2
# Flash Storage, HDD      1
# HDD, HDD                1
# Name: count, dtype: int64

# %%
df['SSD'] = 0
df.loc[df['Memory_Type'] == 'SSD','SSD'] = 1

# %%
df.sample(50)
# Out:
#            Company                                    Product
# laptop_ID
# 1001        Lenovo                         Legion Y520-15IKBN  \
# 856             HP                            Chromebook X360
# 532         Lenovo                              ThinkPad L470
# 82            Dell                              Latitude 5590
# 116             HP                                Probook 440
# 499           Asus                               VivoBook Pro
# 967           Asus                            Chromebook Flip
# 783             HP                              EliteBook 820
# 1162            HP                                Spectre Pro
# 372           Dell                              Inspiron 5770
# 1090        Lenovo                          IdeaPad 300-17ISK
# 556         Lenovo                              ThinkPad T570
# 342           Dell                              Inspiron 7570
# 159         Lenovo                             Yoga 520-14IKB
# 18           Apple                                MacBook Pro
# 290           Acer       SP315-51 (i7-7500U/12GB/1TB/FHD/W10)
# 671             HP        15-ay047nv (i3-6006U/6GB/1TB/Radeon
# 796         Lenovo                         Legion Y520-15IKBN
# 468           Acer                               TravelMate B
# 41            Asus  X540UA-DM186 (i3-6006U/4GB/1TB/FHD/Linux)
# 1316        Lenovo                             Yoga 500-14ISK
# 684           Asus                                  Zenbook 3
# 947         Lenovo                             Yoga 900-13ISK
# 1179           MSI                               GS40 Phantom
# 256           Asus                         ROG G752VSK-GC493T
# 252           Asus                         Rog G701VIK-BA060T
# 776           Dell                              Inspiron 7559
# 778           Acer                             Aspire A315-31
# 1191        Lenovo          V110-15ISK (i5-6200U/4GB/500GB/No
# 279        Toshiba                              Satellite Pro
# 1007        Lenovo                              ThinkPad T560
# 1243          Asus         X540SA-RBPDN09 (N3710/4GB/1TB/W10)
# 636           Dell                                     XPS 15
# 1019            HP                              EliteBook 840
# 1041            HP                                ProBook 640
# 763           Asus                        Pro P2540UA-XO0192R
# 789           Dell                               Alienware 17
# 595         Lenovo                         Ideapad 320-15IKBR
# 32            Asus       E402WA-GA010T (E2-6110/2GB/32GB/W10)
# 355           Dell                              Inspiron 5570
# 654           Acer                                    Swift 3
# 147             HP                                     255 G6
# 84              HP                                ProBook 440
# 510         Lenovo                          IdeaPad 320-14IAP
# 1063          Asus                          Chromebook C202SA
# 584         Lenovo                         IdeaPad Y910-17ISK
# 898           Asus                         Rog GL753VD-GC082T
# 639           Dell                              Inspiron 7567
# 308         Lenovo                         IdeaPad 320-15IKBN
# 1225        Lenovo                          IdeaPad 320-15AST
#
#                      TypeName  Inches                                   Cpu
# laptop_ID
# 1001                   Gaming    15.6           Intel Core i7 7700HQ 2.8GHz  \
# 856        2 in 1 Convertible    11.6  Intel Celeron Dual Core N3350 1.1GHz
# 532                  Notebook    14.0            Intel Core i5 6200U 2.3GHz
# 82                  Ultrabook    15.6            Intel Core i5 8250U 1.6GHz
# 116                  Notebook    14.0            Intel Core i5 8250U 1.6GHz
# 499                    Gaming    15.6           Intel Core i7 7700HQ 2.8GHz
# 967        2 in 1 Convertible    12.5           Intel Core M M7-6Y75 1.2GHz
# 783                 Ultrabook    12.5            Intel Core i5 6200U 2.3GHz
# 1162       2 in 1 Convertible    13.3            Intel Core i7 6600U 2.6GHz
# 372                  Notebook    17.3            Intel Core i5 8250U 1.6GHz
# 1090                 Notebook    17.3            Intel Core i5 6200U 2.3GHz
# 556                  Notebook    15.6            Intel Core i7 7500U 2.7GHz
# 342                 Ultrabook    15.6            Intel Core i5 8250U 1.6GHz
# 159        2 in 1 Convertible    14.0            Intel Core i3 7100U 2.4GHz
# 18                  Ultrabook    15.4                  Intel Core i7 2.9GHz
# 290                  Notebook    15.6            Intel Core i7 7500U 2.7GHz
# 671                  Notebook    15.6              Intel Core i3 6006U 2GHz
# 796                    Gaming    15.6           Intel Core i7 7700HQ 2.8GHz
# 468                   Netbook    11.6  Intel Celeron Dual Core N3060 1.6GHz
# 41                   Notebook    15.6              Intel Core i3 6006U 2GHz
# 1316       2 in 1 Convertible    14.0            Intel Core i7 6500U 2.5GHz
# 684                 Ultrabook    14.0            Intel Core i5 7200U 2.5GHz
# 947        2 in 1 Convertible    13.3            Intel Core i7 6560U 2.2GHz
# 1179                   Gaming    14.0           Intel Core i7 6700HQ 2.6GHz
# 256                    Gaming    17.3           Intel Core i7 7700HQ 2.8GHz
# 252                    Gaming    17.3           Intel Core i7 7820HK 2.9GHz
# 776                    Gaming    15.6           Intel Core i7 6700HQ 2.6GHz
# 778                  Notebook    15.6  Intel Pentium Quad Core N4200 1.1GHz
# 1191                 Notebook    15.6            Intel Core i5 6200U 2.3GHz
# 279                  Notebook    15.6            Intel Core i7 6500U 2.5GHz
# 1007                 Notebook    15.6            Intel Core i5 6200U 2.3GHz
# 1243                 Notebook    15.6  Intel Pentium Quad Core N3710 1.6GHz
# 636                  Notebook    15.6           Intel Core i7 7700HQ 2.8GHz
# 1019                 Notebook    14.0            Intel Core i5 6300U 2.4GHz
# 1041                 Notebook    14.0            Intel Core i5 7200U 2.5GHz
# 763                  Notebook    15.6            Intel Core i7 7500U 2.7GHz
# 789                    Gaming    17.3           Intel Core i7 7700HQ 2.8GHz
# 595                  Notebook    15.6            Intel Core i7 8550U 1.8GHz
# 32                   Notebook    14.0           AMD E-Series E2-6110 1.5GHz
# 355                 Ultrabook    15.6            Intel Core i5 8250U 1.6GHz
# 654                 Ultrabook    14.0            Intel Core i5 7200U 2.5GHz
# 147                  Notebook    15.6             AMD A6-Series 9220 2.5GHz
# 84                   Notebook    14.0            Intel Core i5 8250U 1.6GHz
# 510                  Notebook    14.0  Intel Celeron Dual Core N3350 1.1GHz
# 1063                  Netbook    11.6  Intel Celeron Dual Core N3060 1.6GHz
# 584                    Gaming    17.3           Intel Core i7 6820HK 2.7GHz
# 898                    Gaming    17.3           Intel Core i5 7300HQ 2.5GHz
# 639                    Gaming    15.6           Intel Core i7 7700HQ 2.8GHz
# 308                  Notebook    15.6            Intel Core i5 7200U 2.5GHz
# 1225                 Notebook    15.6              AMD E-Series 9000 2.2GHz
#
#             Ram                         Gpu       OpSys  Weight  Price_euros
# laptop_ID
# 1001        8GB     Nvidia GeForce GTX 1060  Windows 10   2.5kg      1189.00  \
# 856         4GB       Intel HD Graphics 500   Chrome OS   1.4kg       615.00
# 532         8GB       Intel HD Graphics 520   Windows 7  2.02kg      1340.00
# 82          8GB      Intel UHD Graphics 620  Windows 10  1.88kg      1096.16
# 116         4GB      Intel UHD Graphics 620  Windows 10  1.63kg       722.00
# 499         8GB     Nvidia GeForce GTX 1050  Windows 10  1.99kg      1350.00
# 967         8GB       Intel HD Graphics 515   Chrome OS   1.2kg      1159.00
# 783         4GB       Intel HD Graphics 520  Windows 10  1.26kg      1244.00
# 1162        8GB       Intel HD Graphics 520  Windows 10  1.48kg      1799.00
# 372         8GB              AMD Radeon 530  Windows 10   2.8kg      1085.00
# 1090        8GB          AMD Radeon R5 M330  Windows 10   3.0kg       659.00
# 556         8GB       Intel HD Graphics 620  Windows 10  1.99kg      1729.00
# 342         8GB        Nvidia GeForce 940MX  Windows 10   1.9kg      1049.00
# 159         4GB       Intel HD Graphics 620  Windows 10  1.74kg       629.00
# 18         16GB          AMD Radeon Pro 560       macOS  1.83kg      2858.00
# 290        12GB       Intel HD Graphics 620  Windows 10  2.15kg       659.00
# 671         6GB          AMD Radeon R5 M430  Windows 10  2.04kg       539.00
# 796         4GB     Nvidia GeForce GTX 1050  Windows 10   2.4kg       999.00
# 468         4GB       Intel HD Graphics 400  Windows 10   1.4kg       435.00
# 41          4GB       Intel HD Graphics 620       Linux     2kg       389.00
# 1316        4GB       Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 684         8GB       Intel HD Graphics 620  Windows 10   1.1kg      1135.00
# 947        16GB     Intel Iris Graphics 540  Windows 10   1.3kg      1799.00
# 1179       16GB     Nvidia GeForce GTX 970M  Windows 10   1.7kg      1769.00
# 256        16GB     Nvidia GeForce GTX 980M  Windows 10   4.3kg      1799.00
# 252        16GB     Nvidia GeForce GTX 1080  Windows 10   3.6kg      2999.00
# 776        16GB     Nvidia GeForce GTX 960M  Windows 10  2.72kg      1099.00
# 778         4GB       Intel HD Graphics 505       Linux   2.1kg       298.00
# 1191        4GB       Intel HD Graphics 520       No OS   2.1kg       398.00
# 279         8GB         Nvidia GeForce 930M  Windows 10   2.2kg       812.00
# 1007        8GB       Intel HD Graphics 520  Windows 10   2.3kg      1349.00
# 1243        4GB       Intel HD Graphics 405  Windows 10  2.65kg       309.00
# 636         8GB     Nvidia GeForce GTX 1050  Windows 10     2kg      1820.00
# 1019        4GB       Intel HD Graphics 520  Windows 10  1.48kg      1099.99
# 1041        4GB       Intel HD Graphics 620  Windows 10  1.95kg      1060.00
# 763         4GB       Intel HD Graphics 620  Windows 10  2.37kg       849.90
# 789        32GB    Nvidia GeForce GTX 1070M  Windows 10  4.42kg      3588.80
# 595        12GB       Intel HD Graphics 620  Windows 10   2.2kg       609.00
# 32          2GB               AMD Radeon R2  Windows 10  1.65kg       199.00
# 355         8GB              AMD Radeon 530  Windows 10   1.9kg       663.00
# 654         8GB          Intel Graphics 620  Windows 10   1.8kg       919.00
# 147         4GB      AMD Radeon R4 Graphics  Windows 10  1.86kg       369.00
# 84          8GB       Intel HD Graphics 620  Windows 10  1.63kg       860.00
# 510         4GB       Intel HD Graphics 500  Windows 10   2.1kg       299.00
# 1063        4GB       Intel HD Graphics 400   Chrome OS   1.2kg       287.90
# 584        32GB     Nvidia GeForce GTX 1070  Windows 10   4.6kg      2663.00
# 898        12GB     Nvidia GeForce GTX 1050  Windows 10   2.2kg      1369.90
# 639        16GB  Nvidia GeForce GTX 1050 Ti  Windows 10  2.62kg      1479.00
# 308         8GB        Nvidia GeForce 940MX       No OS   2.2kg       549.00
# 1225        4GB      AMD Radeon R2 Graphics  Windows 10   2.2kg       299.00
#
#           Cpu_Company  Memory_Amount    Memory_Type  SSD
# laptop_ID
# 1001            Intel           1152       SSD, HDD    0
# 856             Intel             32  Flash Storage    0
# 532             Intel            256            SSD    1
# 82              Intel            256            SSD    1
# 116             Intel            500            HDD    0
# 499             Intel           1152       SSD, HDD    0
# 967             Intel             64  Flash Storage    0
# 783             Intel            256            SSD    1
# 1162            Intel            256            SSD    1
# 372             Intel           1152       SSD, HDD    0
# 1090            Intel           1024            HDD    0
# 556             Intel            512            SSD    1
# 342             Intel           1152       SSD, HDD    0
# 159             Intel            256            SSD    1
# 18              Intel            512            SSD    1
# 290             Intel           1024            HDD    0
# 671             Intel           1024            HDD    0
# 796             Intel           1024            HDD    0
# 468             Intel            128            SSD    1
# 41              Intel           1024            HDD    0
# 1316            Intel            128            SSD    1
# 684             Intel            256            SSD    1
# 947             Intel           1024            SSD    1
# 1179            Intel           1280       SSD, HDD    0
# 256             Intel           1280       SSD, HDD    0
# 252             Intel            256            SSD    1
# 776             Intel           1152       SSD, HDD    0
# 778             Intel           1024            HDD    0
# 1191            Intel            500            HDD    0
# 279             Intel            500            HDD    0
# 1007            Intel            256            SSD    1
# 1243            Intel           1024            HDD    0
# 636             Intel            256            SSD    1
# 1019            Intel            256            SSD    1
# 1041            Intel            500            HDD    0
# 763             Intel            256            SSD    1
# 789             Intel           2048       SSD, HDD    0
# 595             Intel           1024            HDD    0
# 32                AMD             32  Flash Storage    0
# 355             Intel           1024            HDD    0
# 654             Intel            256            SSD    1
# 147               AMD            256            SSD    1
# 84              Intel            256            SSD    1
# 510             Intel            500            HDD    0
# 1063            Intel             16  Flash Storage    0
# 584             Intel           1280       SSD, HDD    0
# 898             Intel           1152       SSD, HDD    0
# 639             Intel           1280       SSD, HDD    0
# 308             Intel           2048            HDD    0
# 1225              AMD            500            HDD    0

# %%
df['Weight'] = df['Weight'].replace('kg','').astype('float')
df.sample(5)
# Out:
#             Company          Product     TypeName  Inches
# laptop_ID
# 587        Mediacom   SmartBook Edge     Notebook    14.0  \
# 1245           Dell      Vostro 3568     Notebook    15.6
# 405            Dell  Precision M5520  Workstation    15.6
# 1017             HP      Probook 440     Notebook    14.0
# 1139           Asus     VivoBook Max     Notebook    15.6
#
#                                             Cpu  Ram                    Gpu
# laptop_ID
# 587        Intel Celeron Quad Core N3450 1.1GHz  4GB  Intel HD Graphics 500  \
# 1245                 Intel Core i5 7200U 2.5GHz  4GB  Intel HD Graphics 520
# 405                 Intel Core i7 7700HQ 2.8GHz  8GB    Nvidia Quadro M1200
# 1017                 Intel Core i5 7200U 2.5GHz  4GB  Intel HD Graphics 620
# 1139                 Intel Core i3 7100U 2.4GHz  4GB  Intel HD Graphics 620
#
#                 OpSys  Weight  Price_euros Cpu_Company  Memory_Amount
# laptop_ID
# 587        Windows 10    1.45       389.00       Intel             32  \
# 1245            Linux    2.18       521.86       Intel           1024
# 405        Windows 10    1.78      2712.00       Intel            256
# 1017       Windows 10    1.64       779.00       Intel            500
# 1139       Windows 10    2.00       435.00       Intel           1024
#
#           Memory_Type  SSD
# laptop_ID
# 587               SSD    1
# 1245              HDD    0
# 405               SSD    1
# 1017              HDD    0
# 1139              HDD    0

# %%
df.dtypes
# Out:
# Company           object
# Product           object
# TypeName          object
# Inches           float64
# Cpu               object
# Ram               object
# Gpu               object
# OpSys             object
# Weight           float64
# Price_euros      float64
# Cpu_Company       object
# Memory_Amount      int64
# Memory_Type       object
# SSD                int64
# dtype: object

# %% [markdown]
# Создайте датафрейм с клиентами:
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
# laptop_id - это индексы датафрейма с ноутбуками
# 3.1 Присоедините к таблице clients данные по ноутбукам через метод join
# 3.2 Присоедините к таблице clients данные по ноутбукам через метод merge
# Это нужно, чтобы понимать, какие ноутбуки покупались клиентами

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]})

# %%
clients = clients.set_index('laptop_id')

# %%
df1 = df.join(clients, how = 'outer')
df1
# Out:
#      Company                              Product            TypeName  Inches
# 1      Apple                          MacBook Pro           Ultrabook    13.3  \
# 2      Apple                          Macbook Air           Ultrabook    13.3
# 3         HP                               250 G6            Notebook    15.6
# 4      Apple                          MacBook Pro           Ultrabook    15.4
# 5      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1317  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1318  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
# 1999     NaN                                  NaN                 NaN     NaN
#
#                                        Cpu   Ram
# 1                     Intel Core i5 2.3GHz   8GB  \
# 2                     Intel Core i5 1.8GHz   8GB
# 3               Intel Core i5 7200U 2.5GHz   8GB
# 4                     Intel Core i7 2.7GHz  16GB
# 5                     Intel Core i5 3.1GHz   8GB
# ...                                    ...   ...
# 1317            Intel Core i7 6500U 2.5GHz  16GB
# 1318  Intel Celeron Dual Core N3050 1.6GHz   2GB
# 1319            Intel Core i7 6500U 2.5GHz   6GB
# 1320  Intel Celeron Dual Core N3050 1.6GHz   4GB
# 1999                                   NaN   NaN
#
#                                Gpu       OpSys  Weight  Price_euros
# 1     Intel Iris Plus Graphics 640       macOS    1.37      1339.69  \
# 2           Intel HD Graphics 6000       macOS    1.34       898.94
# 3            Intel HD Graphics 620       No OS    1.86       575.00
# 4               AMD Radeon Pro 455       macOS    1.83      2537.45
# 5     Intel Iris Plus Graphics 650       macOS    1.37      1803.60
# ...                            ...         ...     ...          ...
# 1317         Intel HD Graphics 520  Windows 10    1.30      1499.00
# 1318             Intel HD Graphics  Windows 10    1.50       229.00
# 1319            AMD Radeon R5 M330  Windows 10    2.19       764.00
# 1320             Intel HD Graphics  Windows 10    2.20       369.00
# 1999                           NaN         NaN     NaN          NaN
#
#      Cpu_Company  Memory_Amount    Memory_Type  SSD  client_id
# 1          Intel          128.0            SSD  1.0        NaN
# 2          Intel          128.0  Flash Storage  0.0        NaN
# 3          Intel          256.0            SSD  1.0        NaN
# 4          Intel          512.0            SSD  1.0        NaN
# 5          Intel          256.0            SSD  1.0        NaN
# ...          ...            ...            ...  ...        ...
# 1317       Intel          512.0            SSD  1.0        NaN
# 1318       Intel           64.0  Flash Storage  0.0        NaN
# 1319       Intel         1024.0            HDD  0.0        NaN
# 1320       Intel          500.0            HDD  0.0        NaN
# 1999         NaN            NaN            NaN  NaN       43.0
#
# [1305 rows x 15 columns]

# %%
df1.loc[[506, 398, 710, 120, 1999]]
# Out:
#      Company            Product  TypeName  Inches
# 506   Lenovo      ThinkPad L570  Notebook    15.6  \
# 398      NaN                NaN       NaN     NaN
# 710   Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 120     Dell      Inspiron 7570  Notebook    15.6
# 1999     NaN                NaN       NaN     NaN
#
#                               Cpu  Ram                    Gpu       OpSys
# 506    Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10  \
# 398                           NaN  NaN                    NaN         NaN
# 710   AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 120    Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
# 1999                          NaN  NaN                    NaN         NaN
#
#       Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 506     2.30       911.00       Intel          256.0         SSD  1.0  \
# 398      NaN          NaN         NaN            NaN         NaN  NaN
# 710     2.20       429.00         AMD         1024.0         HDD  0.0
# 120     2.16      1130.33       Intel         1280.0    SSD, HDD  0.0
# 1999     NaN          NaN         NaN            NaN         NaN  NaN
#
#       client_id
# 506        45.0
# 398        32.0
# 710        67.0
# 120        33.0
# 1999       43.0

# %%
df2 = clients.merge(df,left_on = 'laptop_id', right_on = 'laptop_ID')

# %%
df2
# Out:
#    client_id Company            Product  TypeName  Inches
# 0         45  Lenovo      ThinkPad L570  Notebook    15.6  \
# 1         67  Lenovo  IdeaPad 320-15ABR  Notebook    15.6
# 2         33    Dell      Inspiron 7570  Notebook    15.6
#
#                            Cpu  Ram                    Gpu       OpSys
# 0   Intel Core i5 7200U 2.5GHz  8GB  Intel HD Graphics 620  Windows 10  \
# 1  AMD A12-Series 9720P 3.6GHz  8GB          AMD Radeon R7  Windows 10
# 2   Intel Core i7 8550U 1.8GHz  8GB   Nvidia GeForce 940MX  Windows 10
#
#    Weight  Price_euros Cpu_Company  Memory_Amount Memory_Type  SSD
# 0    2.30       911.00       Intel            256         SSD    1
# 1    2.20       429.00         AMD           1024         HDD    0
# 2    2.16      1130.33       Intel           1280    SSD, HDD    0

# %% [markdown]
# 4.1 Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей
# 4.2 Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора
# 4.3 Постройте таблицу с подсчетом количества ноутбуков в данных в зависимости от производителя CPU и ОЗУ
# 4.4 Постройте таблицу с подсчетом средней стоимости ноутбуков в данных в зависимости от операционной системы и GB памяти

# %%
df.groupby('Company').agg({'Price_euros':'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %%
df.groupby('Cpu_Company').agg({'Price_euros':['min','mean','max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0

# %%
df.pivot_table(index = 'Cpu_Company',
              columns = 'Ram',
              values = 'Price_euros',
              aggfunc = 'count',
              fill_value = 0)
# Out:
# Ram          12GB  16GB  24GB  2GB  32GB  4GB  64GB  6GB  8GB
# Cpu_Company
# AMD             2     3     0    1     0   31     0   13   12
# Intel          23   197     3   21    17  343     1   28  607
# Samsung         0     0     0    0     0    1     0    0    0

# %%
df.pivot_table(index = 'OpSys',
              columns = 'Memory_Amount',
              values = 'Price_euros',
              aggfunc = 'mean',
              fill_value = 0)
# Out:
# Memory_Amount  8       16          32          64           128     180
# OpSys
# Android           0    0.00    0.000000  434.000000     0.000000     0.0  \
# Chrome OS         0  305.38  412.454545  774.333333  1275.000000     0.0
# Linux             0    0.00    0.000000    0.000000   490.500000     0.0
# Mac OS X          0    0.00    0.000000    0.000000  1099.000000     0.0
# No OS             0    0.00    0.000000    0.000000   362.024000     0.0
# Windows 10     2249    0.00  270.001471  333.795556   673.385692  1073.5
# Windows 10 S      0    0.00    0.000000  308.995000  1039.000000     0.0
# Windows 7         0    0.00    0.000000    0.000000  1320.323333  1199.0
# macOS             0    0.00    0.000000    0.000000  1119.315000     0.0
#
# Memory_Amount  240          256         500   508   ...     768          1024
# OpSys                                               ...
# Android           0     0.000000    0.000000     0  ...     0.00     0.000000  \
# Chrome OS         0  1559.000000    0.000000     0  ...     0.00     0.000000
# Linux             0   795.814000  389.056364     0  ...     0.00   581.401290
# Mac OS X          0  1311.994000    0.000000     0  ...     0.00     0.000000
# No OS             0   754.834615  404.675385     0  ...     0.00   540.539600
# Windows 10     3100  1214.518551  664.717647     0  ...  1607.96   880.695661
# Windows 10 S      0  1668.950000    0.000000     0  ...     0.00     0.000000
# Windows 7         0  1846.466800  924.048333  1002  ...     0.00  1539.666667
# macOS             0  1600.370000    0.000000     0  ...     0.00     0.000000
#
# Memory_Amount  1088         1152         1280         1536         2048
# OpSys
# Android           0     0.000000     0.000000     0.000000     0.000000  \
# Chrome OS         0     0.000000     0.000000     0.000000     0.000000
# Linux             0   994.000000     0.000000     0.000000     0.000000
# Mac OS X          0     0.000000     0.000000     0.000000     0.000000
# No OS             0   895.666667  1149.000000     0.000000   594.000000
# Windows 10     1993  1285.464494  1878.083562  2549.750667  1058.201333
# Windows 10 S      0     0.000000     0.000000     0.000000     0.000000
# Windows 7         0     0.000000     0.000000     0.000000     0.000000
# macOS             0     0.000000     0.000000     0.000000     0.000000
#
# Memory_Amount    2176         2304  2560
# OpSys
# Android          0.00     0.000000     0
# Chrome OS        0.00     0.000000     0
# Linux            0.00  1049.000000     0
# Mac OS X         0.00     0.000000     0
# No OS            0.00     0.000000     0
# Windows 10     977.95  1590.015556  1849
# Windows 10 S     0.00     0.000000     0
# Windows 7        0.00     0.000000     0
# macOS            0.00     0.000000     0
#
# [9 rows x 22 columns]

# %%
df.groupby(['OpSys','Memory_Amount']).agg({'Price_euros':'mean'}).unstack('Memory_Amount').fillna(0)
# Out:
#               Price_euros
# Memory_Amount        8       16          32          64           128
# OpSys
# Android               0.0    0.00    0.000000  434.000000     0.000000  \
# Chrome OS             0.0  305.38  412.454545  774.333333  1275.000000
# Linux                 0.0    0.00    0.000000    0.000000   490.500000
# Mac OS X              0.0    0.00    0.000000    0.000000  1099.000000
# No OS                 0.0    0.00    0.000000    0.000000   362.024000
# Windows 10         2249.0    0.00  270.001471  333.795556   673.385692
# Windows 10 S          0.0    0.00    0.000000  308.995000  1039.000000
# Windows 7             0.0    0.00    0.000000    0.000000  1320.323333
# macOS                 0.0    0.00    0.000000    0.000000  1119.315000
#
#                                                                 ...
# Memory_Amount    180     240          256         500     508   ...     768
# OpSys                                                           ...
# Android           0.0     0.0     0.000000    0.000000     0.0  ...     0.00  \
# Chrome OS         0.0     0.0  1559.000000    0.000000     0.0  ...     0.00
# Linux             0.0     0.0   795.814000  389.056364     0.0  ...     0.00
# Mac OS X          0.0     0.0  1311.994000    0.000000     0.0  ...     0.00
# No OS             0.0     0.0   754.834615  404.675385     0.0  ...     0.00
# Windows 10     1073.5  3100.0  1214.518551  664.717647     0.0  ...  1607.96
# Windows 10 S      0.0     0.0  1668.950000    0.000000     0.0  ...     0.00
# Windows 7      1199.0     0.0  1846.466800  924.048333  1002.0  ...     0.00
# macOS             0.0     0.0  1600.370000    0.000000     0.0  ...     0.00
#
#
# Memory_Amount         1024    1088         1152         1280         1536
# OpSys
# Android           0.000000     0.0     0.000000     0.000000     0.000000  \
# Chrome OS         0.000000     0.0     0.000000     0.000000     0.000000
# Linux           581.401290     0.0   994.000000     0.000000     0.000000
# Mac OS X          0.000000     0.0     0.000000     0.000000     0.000000
# No OS           540.539600     0.0   895.666667  1149.000000     0.000000
# Windows 10      880.695661  1993.0  1285.464494  1878.083562  2549.750667
# Windows 10 S      0.000000     0.0     0.000000     0.000000     0.000000
# Windows 7      1539.666667     0.0     0.000000     0.000000     0.000000
# macOS             0.000000     0.0     0.000000     0.000000     0.000000
#
#
# Memory_Amount         2048    2176         2304    2560
# OpSys
# Android           0.000000    0.00     0.000000     0.0
# Chrome OS         0.000000    0.00     0.000000     0.0
# Linux             0.000000    0.00  1049.000000     0.0
# Mac OS X          0.000000    0.00     0.000000     0.0
# No OS           594.000000    0.00     0.000000     0.0
# Windows 10     1058.201333  977.95  1590.015556  1849.0
# Windows 10 S      0.000000    0.00     0.000000     0.0
# Windows 7         0.000000    0.00     0.000000     0.0
# macOS             0.000000    0.00     0.000000     0.0
#
# [9 rows x 22 columns]

# %% [markdown]
# 5.1 Ноутбуков каких компаний и с каким процессором больше?
# 5.2 С каким типом памяти и с каким объемом памяти больше ноутбуков?

# %%
pd.crosstab(index = df.Company,
           columns = df.Cpu_Company)
# Out:
# Cpu_Company  AMD  Intel  Samsung
# Company
# Acer          10     93        0
# Apple          0     21        0
# Asus          11    147        0
# Chuwi          0      3        0
# Dell           0    297        0
# Fujitsu        0      3        0
# Google         0      3        0
# HP            25    249        0
# Huawei         0      2        0
# LG             0      3        0
# Lenovo        16    281        0
# MSI            0     54        0
# Mediacom       0      7        0
# Microsoft      0      6        0
# Razer          0      7        0
# Samsung        0      8        1
# Toshiba        0     48        0
# Vero           0      4        0
# Xiaomi         0      4        0

# %%
pd.crosstab(index = df.Memory_Type,
           columns = df.Memory_Amount)
# Out:
# Memory_Amount       8     16    32    64    128   180   240   256   500
# Memory_Type
# Flash Storage          0     7    38    15     4     0     0     8     0  \
# Flash Storage, HDD     0     0     0     0     0     0     0     0     0
# HDD                    0     0     1     0     1     0     0     0   132
# HDD, HDD               0     0     0     0     0     0     0     0     0
# Hybrid                 0     0     0     0     0     0     0     0     0
# SSD                    1     3     6     1    76     5     1   412     0
# SSD, HDD               0     0     0     0     0     0     0     0     0
# SSD, Hybrid            0     0     0     0     0     0     0     0     0
# SSD, SSD               0     0     0     0     0     0     0     0     0
#
# Memory_Amount       508   ...  768   1024  1088  1152  1280  1536  2048  2176
# Memory_Type               ...
# Flash Storage          0  ...     0     0     0     0     0     0     0     0  \
# Flash Storage, HDD     0  ...     0     0     1     0     0     0     0     0
# HDD                    0  ...     0   224     0     0     0     0    16     0
# HDD, HDD               0  ...     0     0     0     0     0     0     1     0
# Hybrid                 1  ...     0     9     0     0     0     0     0     0
# SSD                    0  ...     0    14     0     0     0     0     0     0
# SSD, HDD               0  ...     0     0     0    94    73    14     2     2
# SSD, Hybrid            0  ...     0     0     0     0     1     1     0     0
# SSD, SSD               0  ...     1     1     0     0     0     0     0     0
#
# Memory_Amount       2304  2560
# Memory_Type
# Flash Storage          0     0
# Flash Storage, HDD     0     0
# HDD                    0     0
# HDD, HDD               0     0
# Hybrid                 0     0
# SSD                    0     0
# SSD, HDD              10     3
# SSD, Hybrid            0     0
# SSD, SSD               0     0
#
# [9 rows x 22 columns]
