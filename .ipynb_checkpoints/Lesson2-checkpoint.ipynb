# %%
import pandas as pd
df = pd.read_csv("Lesson2.csv", sep=';')

# %%
# подключаем модуль pathlib и библиотеку Path модуля pathlib
# если pathlib не установлен, сделать это можно
# с помощью команды pip install pathlib 
import pathlib
from pathlib import Path
 
#Получаем строку, содержащую путь к рабочей директории:
work_path = pathlib.Path.cwd()
print(work_path)
# Out:
# C:\Users\Alex\YandexDisk\Компьютер KOMPAS\Документы\GeekBrains\Python_Analiz

# %%
df
# Out:
#        num            date_time  ulica  dom kvartira  kategoria  \
# 0      915  2015-10-06 10:51:00      1  NaN      NaN          2
# 1      909  2015-10-05 14:56:00      1  NaN      NaN          1
# 2      914  2015-10-05 16:35:00      1  NaN      NaN          1
# 3      912  2015-10-01 16:33:00      1  NaN      NaN          1
# 4      913  2015-10-02 16:34:00      1  NaN      NaN          1
# ...    ...                  ...    ...  ...      ...        ...
# 4445  5410  2023-05-23 20:48:00      1  NaN      NaN          1
# 4446  5411  2023-05-24 09:24:00      1  NaN      NaN          1
# 4447  5412  2023-05-24 14:15:24      1  NaN      NaN          1
# 4448  5413  2023-05-25 09:32:00      1                        1
# 4449  5414  2023-05-25 09:34:27      1                        1
#
#                                                   diagn  Fl_vyp  master  \
# 0                              Залипла кнопка включения       2       4
# 1                               Мало места на диске "С"       2       1
# 2                                           Не работает       2       7
# 3                                           Не работает       2       7
# 4                                Не воспроизводит диски       2       7
# ...                                                 ...     ...     ...
# 4445                         не работает много программ       6       1
# 4446                          новый ноут. установить ПО       2       1
# 4447                       БП греется, ПК не включается       1       1
# 4448  не загружается. При входе в пользователя выдаё...       1       1
# 4449  необходимо подготовить ПК к работе на новом ме...       1       1
#
#       sdelano  ... responsible earned device  predoplata  \
# 0         NaN  ...         NaN      0      2           0
# 1         NaN  ...         NaN      0      1           0
# 2         NaN  ...         NaN      0      7           0
# 3         NaN  ...         NaN      0      7           0
# 4         NaN  ...         NaN      0      7           0
# ...       ...  ...         ...    ...    ...         ...
# 4445      NaN  ...         NaN      0      1           0
# 4446      NaN  ...         NaN   1600      2           0
# 4447      NaN  ...         NaN      0      1           0
# 4448      NaN  ...         NaN      0      1           0
# 4449      NaN  ...         NaN      0      1           0
#
#                               opis_dev                     fio soglsovat  \
# 0                         Packard bell          Старков Андрей         0
# 1                                  NaN         Аракелян Вардан         0
# 2        Флеш-накопитель Silicon Power           Алексей Мосин         0
# 3     Универсальный блок питания JET.A         Шаврина Наталья         0
# 4                   Проигрыватель Sony   Алексей Мосин(Черных)         0
# ...                                ...                     ...       ...
# 4445                               NaN       бухгалтерия Елена         0
# 4446               Lenovo V15 G2 + ЗУ              Контрактник         0
# 4447                               NaN        каб. информатики         0
# 4448                               NaN  Звукорежисёр(137 каб.)         0
# 4449                               NaN              библиотека         0
#
#      roditel        serial  Ur_Lico
# 0          0           NaN        1
# 1          0           NaN        1
# 2          0           NaN        1
# 3          0           NaN        1
# 4          0           NaN        1
# ...      ...           ...      ...
# 4445       0           NaN        7
# 4446       0           NaN       11
# 4447       0           NaN        4
# 4448    5340  110134000655       11
# 4449       0       8300381        3
#
# [4450 rows x 31 columns]
